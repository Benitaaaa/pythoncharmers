# %% [markdown]
# ### INSTALL REQUIRED PACKAGE

# %%
#!pip install textblob
#!pip install pycountry #this is to standardize all country names
#!pip install pandas openpyxl requests beautifulsoup4 spacy transformers pyvis
#!pip install pycountry-convert
#!pip install PyPDF2 pandas networkx spacy nltk tensorflow transformers textblob pyvis pycountry numpy

# %% [markdown]
# ### IMPORT REQUIRED PACKAGE

# %%
import os
import PyPDF2
import pandas as pd
import networkx as nx
from collections import defaultdict
from pathlib import Path
import spacy
import nltk
import tensorflow as tf
from transformers import pipeline
from textblob import TextBlob
from pyvis.network import Network
import pycountry
net = Network(notebook=True)
import numpy as np

import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %%
#!python -m spacy download en_core_web_sm

# %% [markdown]
# ### LOAD the CSV file

# %%
# Load the uploaded CSV file
file_path = "/Users/benitaleonardi/Documents/news_excerpts_parsed.csv"
df = pd.read_csv(file_path)

# first few rows of the datas

# %%
df.head()
# Out:
#                                                 Link  \
# 0  https://edition.cnn.com/2023/09/29/business/st...
# 1  https://www.channelnewsasia.com/singapore/su-w...
# 2  https://edition.cnn.com/2023/05/22/tech/meta-f...
# 3  https://www.channelnewsasia.com/singapore/bill...
# 4  https://edition.cnn.com/2024/03/05/politics/li...
#
#                                                 Text
# 0  Starbucks violated federal labor law when it i...
# 1  The first suspect to plead guilty in Singapore...
# 2  Meta has been fined a record-breaking €1.2 bil...
# 3  SINGAPORE: A 45-year-old man linked to Singapo...
# 4  The Department of Education imposed a record $...

# %%
df.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.size()
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### LOAD the PDFs

# %%
# VERSION 1

import requests
from bs4 import BeautifulSoup
import spacy
import pycountry
from collections import defaultdict
from transformers import pipeline
from pyvis.network import Network
import pandas as pd

# Load SpaCy NLP model
nlp = spacy.load("en_core_web_sm")

# Load Hugging Face Transformers Sentiment Model
sentiment_pipeline = pipeline('sentiment-analysis', model='distilbert-base-uncased-finetuned-sst-2-english')

class CountrySentimentAnalyzer:
    def __init__(self):
        """Initialize the text analyzer with NLP and data structures."""
        self.nlp = nlp  # Use loaded SpaCy model
        self.entities = defaultdict(set)
        self.relationships = []

    def standardize_country_name(self, country):
        """Attempt to standardize country names using pycountry."""
        try:
            return pycountry.countries.lookup(country).name
        except LookupError:
            return None  # Ignore non-country entities

    def get_sentiment(self, sentence):
        """Analyze sentiment of a sentence using Transformers."""
        result = sentiment_pipeline(sentence)
        sentiment_label = result[0]['label']  # 'POSITIVE' or 'NEGATIVE'
        confidence = result[0]['score']

        # If confidence is low, classify as NEUTRAL
        if confidence < 0.7:
            return 'NEUTRAL'
        return sentiment_label

    def extract_entities_and_relationships(self, text, source=None):
        """Extract country entities (GPE) and relationships from text."""
        doc = self.nlp(text)
        country_entities = set()

        for ent in doc.ents:
            if ent.label_ == "GPE":
                country_name = self.standardize_country_name(ent.text)
                if country_name:  # Only add valid countries
                    country_entities.add((country_name, source))

        # Store valid countries
        for country in country_entities:
            self.entities['GPE'].add(country)

        # Create relationships between countries in the same sentence
        for sent in doc.sents:
            sent_doc = self.nlp(sent.text)
            entities_in_sent = [self.standardize_country_name(e.text) for e in sent_doc.ents if e.label_ == "GPE"]
            entities_in_sent = [e for e in entities_in_sent if e]  # Remove None values

            if len(entities_in_sent) >= 2:
                sentiment = self.get_sentiment(sent.text)  # Get sentiment of the sentence
                for i in range(len(entities_in_sent) - 1):
                    self.relationships.append({
                        'source': entities_in_sent[i],
                        'target': entities_in_sent[i + 1],
                        'sentence': sent.text,
                        'sentiment': sentiment
                    })

    def scrape_webpage(self, url):
        """Scrape webpage content from a given URL."""
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, "html.parser")
            paragraphs = [p.text for p in soup.find_all("p")]
            return " ".join(paragraphs)  # Return all text as a single string
        except requests.RequestException as e:
            print(f"Failed to fetch {url}: {e}")
            return ""

    def process_csv(self, csv_file):
        """Process CSV file and analyze extracted text."""
        df = pd.read_csv(csv_file)

        for _, row in df.iterrows():
            link = row.get("Link", "").strip()
            text = row.get("Text", "").strip()

            if link:
                print(f"Scraping: {link}")
                web_text = self.scrape_webpage(link)
                self.extract_entities_and_relationships(web_text, source=link)
            
            if text:
                self.extract_entities_and_relationships(text, source="CSV Data")

    def visualize_relationships(self, output_file="country_network.html"):
        """Visualize country relationships using Pyvis with sentiment-based colors."""
        net = Network(height="750px", width="100%", bgcolor="#222222", font_color="white", notebook=True, cdn_resources='in_line')

        # Add nodes (countries)
        countries = set()
        for relation in self.relationships:
            countries.add(relation['source'])
            countries.add(relation['target'])

        for country in countries:
            net.add_node(country, label=country, color="blue", size=15)

        # Add edges with sentiment-based color
        for relation in self.relationships:
            sentiment = relation['sentiment']
            if sentiment == "POSITIVE":
                edge_color = "green"
            elif sentiment == "NEGATIVE":
                edge_color = "red"
            else:
                edge_color = "gray"

            net.add_edge(relation['source'], relation['target'], width=2, color=edge_color, title=relation['sentence'])

        # Save and show visualization
        net.show(output_file)

if __name__ == "__main__":
    csv_file = "/Users/benitaleonardi/Documents/news_excerpts_parsed_mini.csv"

    analyzer = CountrySentimentAnalyzer()

    # Process CSV data (scrape web content and analyze text)
    analyzer.process_csv(csv_file)

    # Visualize the combined network from CSV data
    analyzer.visualize_relationships("country_network_scrape.html")
# Out:
# Device set to use mps:0
# Scraping: https://edition.cnn.com/2023/09/29/business/starbucks-union-wages/index.html
# Scraping: https://www.channelnewsasia.com/singapore/su-wenqiang-pleads-guilty-billion-dollar-money-laundering-convicted-4234731
# Scraping: https://edition.cnn.com/2023/05/22/tech/meta-facebook-data-privacy-eu-fine/index.html
# Scraping: https://www.channelnewsasia.com/singapore/billion-dollar-money-laundering-case-zhang-ruijin-sentenced-15-months-jail-4302416
# Scraping: https://edition.cnn.com/2024/03/05/politics/liberty-university-fined-campus-safety/index.html
# Scraping: https://www.euronews.com/2024/02/23/judge-convicts-former-austrian-chancellor-sebastian-kurz
# Scraping: https://edition.cnn.com/2022/07/21/economy/china-fines-didi-data-law-violation-intl-hnk/index.html
# Scraping: https://www.brusselstimes.com/justice-belgium/1011990/two-alleged-leaders-of-vast-drug-trafficking-operation-looking-at-20-years-in-prison
# Failed to fetch https://www.brusselstimes.com/justice-belgium/1011990/two-alleged-leaders-of-vast-drug-trafficking-operation-looking-at-20-years-in-prison: HTTPSConnectionPool(host='www.brusselstimes.com', port=443): Read timed out. (read timeout=10)
# Scraping: https://www.expats.cz/czech-news/article/former-czech-mp-gets-three-year-jail-term-for-multiple-charges-of-rape
# Scraping: https://www.thelocal.dk/20240311/british-trader-on-trial-in-denmark-for-massive-fraud
# Failed to fetch https://www.thelocal.dk/20240311/british-trader-on-trial-in-denmark-for-massive-fraud: 403 Client Error: Forbidden for url: https://www.thelocal.dk/20240311/british-trader-on-trial-in-denmark-for-massive-fraud
# Scraping: https://edition.cnn.com/2022/08/02/europe/brittney-griner-trial-russia-tuesday/index.html
# Scraping: https://edition.cnn.com/2018/04/16/politics/pruitt-soundproof-booth/index.html
# Scraping: https://news.postimees.ee/7416922/estonian-police-nab-boss-of-lithuanian-car-thieves
# Scraping: https://yle.fi/a/3-12659444
# Scraping: https://icelandmonitor.mbl.is/news/news/2021/10/21/sentenced_to_16_years_in_prison/
# Scraping: https://www.ndtv.com/world-news/renault-nissan-alliance-carlos-ghosn-france-issues-international-arrest-warrant-against-ex-nissan-head-2909763
# Scraping: https://edition.cnn.com/2023/04/19/tech/china-seagate-huawei-penalty-hnk-intl/index.html
# Scraping: https://www.channelnewsasia.com/asia/woman-plead-guilty-negligence-caring-2-babies-nurul-shahira-3504176
# Scraping: https://edition.cnn.com/2023/05/03/business/mcdonalds-child-labor-louisville/index.html
# Scraping: https://edition.cnn.com/2023/04/07/europe/russia-chinese-lgbtq-blogger-arrested-intl/index.html
# Scraping: https://edition.cnn.com/2021/07/30/tech/amazon-eu-privacy-fine/index.html
# Scraping: https://edition.cnn.com/2024/03/07/europe/portugal-election-intl-cmd/index.html
# Scraping: https://edition.cnn.com/2010/WORLD/europe/10/20/czech.republic.arson.verdict/index.html
# Failed to fetch https://edition.cnn.com/2010/WORLD/europe/10/20/czech.republic.arson.verdict/index.html: 404 Client Error: OK for url: https://edition.cnn.com/2010/WORLD/europe/10/20/czech.republic.arson.verdict/index.html
# Scraping: https://www.channelnewsasia.com/asia/tony-chung-exiled-activist-hong-kong-says-paid-informant-china-4016916
# Scraping: https://edition.cnn.com/2024/01/22/europe/ian-bailey-murder-dead-scli-intl/index.html
# Scraping: https://edition.cnn.com/2020/06/15/sport/daniel-kinahan-tyson-fury-anthony-joshua-boxing-ireland-spt-intl/index.html
# Scraping: https://www.channelnewsasia.com/singapore/red-crowns-senior-living-fined-offence-nursing-home-alternative-4233926
# Scraping: https://www.straitstimes.com/singapore/all-natural-eczema-cream-found-to-have-over-430-times-the-allowed-limit-of-arsenic-hsa
# Scraping: https://edition.cnn.com/2022/12/06/politics/trump-organization-fraud-trial-verdict/index.html
# Scraping: https://www.straitstimes.com/singapore/courts-crime/company-director-gets-20-months-jail-152m-penalty-for-offences-related-to-iras-scheme
# Scraping: https://www.channelnewsasia.com/world/greta-thunberg-charged-again-disobeying-police-order-3773416
# Failed to fetch https://www.channelnewsasia.com/world/greta-thunberg-charged-again-disobeying-police-order-3773416: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/greta-thunberg-charged-again-disobeying-police-order-3773416
# Scraping: https://www.reuters.com/world/china/hong-kong-court-convicts-four-rioting-after-2019-legislature-storming-2024-02-01/
# Failed to fetch https://www.reuters.com/world/china/hong-kong-court-convicts-four-rioting-after-2019-legislature-storming-2024-02-01/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/world/china/hong-kong-court-convicts-four-rioting-after-2019-legislature-storming-2024-02-01/
# Scraping: https://edition.cnn.com/2020/01/19/us/alaska-dentist-hoverboard-convicted-trnd/index.html
# Scraping: https://www.channelnewsasia.com/asia/vietnam-court-jails-soft-drinks-tycoon-40-miilion-scam-case-tan-hiep-phat-4291091
# Failed to fetch https://www.channelnewsasia.com/asia/vietnam-court-jails-soft-drinks-tycoon-40-miilion-scam-case-tan-hiep-phat-4291091: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/vietnam-court-jails-soft-drinks-tycoon-40-miilion-scam-case-tan-hiep-phat-4291091
# Scraping: https://www.straitstimes.com/singapore/courts-crime/mfa-director-general-charged-over-use-of-diplomatic-bags-containing-panadol-luxury-watches
# Scraping: https://www.straitstimes.com/tech/tech-news/singapore-firms-fined-75000-for-personal-data-lapses-affecting-over-600000-people
# Scraping: https://www.reuters.com/business/finance/indias-paytm-payments-bank-fined-over-662000-money-laundering-2024-03-01/
# Failed to fetch https://www.reuters.com/business/finance/indias-paytm-payments-bank-fined-over-662000-money-laundering-2024-03-01/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/business/finance/indias-paytm-payments-bank-fined-over-662000-money-laundering-2024-03-01/
# Scraping: https://edition.cnn.com/2023/04/04/business/tiktok-uk-data-regulator-fine/index.html
# Scraping: https://www.channelnewsasia.com/singapore/mas-fines-dbs-ocbc-citibank-swiss-life-breaches-3-8-million-wirecard-3577456
# Scraping: https://www.reuters.com/business/aerospace-defense/indias-aviation-watchdog-fines-air-india-violating-flight-duty-time-limitations-2024-03-22/
# Failed to fetch https://www.reuters.com/business/aerospace-defense/indias-aviation-watchdog-fines-air-india-violating-flight-duty-time-limitations-2024-03-22/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/business/aerospace-defense/indias-aviation-watchdog-fines-air-india-violating-flight-duty-time-limitations-2024-03-22/
# Scraping: https://edition.cnn.com/2022/12/20/investing/wells-fargo-cfpb-foreclosure-fine/index.html
# Scraping: https://www.straitstimes.com/business/apple-hit-with-18-billion-eu-fine-over-app-store-rules
# Scraping: https://www.straitstimes.com/singapore/burger-lobster-fined-3000-for-food-safety-lapses
# Scraping: https://edition.cnn.com/2024/02/22/tech/ftc-avast-cybersecurity-company-fine/index.html
# Scraping: https://www.cbsnews.com/news/dish-fcc-satellite-space-junk-settlement/
# Scraping: https://www.cnbc.com/2022/07/21/china-fines-didi-more-than-1-billion-for-breaking-data-security-laws.html
# Scraping: https://edition.cnn.com/2024/03/23/us/oregon-cold-case-chewing-gum-dna/index.html
# Scraping: https://www.reuters.com/technology/space/musks-spacex-fined-near-amputation-suffered-by-worker-records-show-2024-02-13/
# Failed to fetch https://www.reuters.com/technology/space/musks-spacex-fined-near-amputation-suffered-by-worker-records-show-2024-02-13/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/space/musks-spacex-fined-near-amputation-suffered-by-worker-records-show-2024-02-13/
# Scraping: https://www.reuters.com/world/us/us-regulators-fine-credit-firm-transunion-23-million-over-rent-screening-2023-10-12/
# Failed to fetch https://www.reuters.com/world/us/us-regulators-fine-credit-firm-transunion-23-million-over-rent-screening-2023-10-12/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/world/us/us-regulators-fine-credit-firm-transunion-23-million-over-rent-screening-2023-10-12/
# Scraping: https://www.reuters.com/technology/russian-court-fines-google-508-mln-over-fake-information-ukraine-war-tass-2023-12-20/
# Failed to fetch https://www.reuters.com/technology/russian-court-fines-google-508-mln-over-fake-information-ukraine-war-tass-2023-12-20/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/russian-court-fines-google-508-mln-over-fake-information-ukraine-war-tass-2023-12-20/
# Scraping: https://www.reuters.com/markets/asia/indonesias-anti-trust-body-fines-cooking-oil-firms-restricting-supply-2023-05-26/
# Failed to fetch https://www.reuters.com/markets/asia/indonesias-anti-trust-body-fines-cooking-oil-firms-restricting-supply-2023-05-26/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/markets/asia/indonesias-anti-trust-body-fines-cooking-oil-firms-restricting-supply-2023-05-26/
# Scraping: https://edition.cnn.com/2024/03/06/entertainment/rust-trial-hannah-gutierrez-reed/index.html
# Scraping: https://www.reuters.com/sustainability/boards-policy-regulation/adm-investor-services-fined-anti-money-laundering-failures-2023-10-02/
# Failed to fetch https://www.reuters.com/sustainability/boards-policy-regulation/adm-investor-services-fined-anti-money-laundering-failures-2023-10-02/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/sustainability/boards-policy-regulation/adm-investor-services-fined-anti-money-laundering-failures-2023-10-02/
# Scraping: https://edition.cnn.com/2024/03/14/tech/tiktok-fine-italy/index.html
# Scraping: https://www.nasdaq.com/articles/italys-antitrust-agency-fines-energy-companies-for-aggressive-billing-0
# Failed to fetch https://www.nasdaq.com/articles/italys-antitrust-agency-fines-energy-companies-for-aggressive-billing-0: HTTPSConnectionPool(host='www.nasdaq.com', port=443): Read timed out. (read timeout=10)
# Scraping: https://edition.cnn.com/2024/03/20/travel/delta-pilot-sentenced-intl-scli-gbr/index.html
# Scraping: https://edition.cnn.com/2024/04/30/business/binance-founder-sentenced-money-laundering/index.html
# Scraping: https://www.straitstimes.com/life/entertainment/iranian-director-mohammad-rasoulof-sentenced-to-8-years-in-prison-and-flogging-lawyer
# Scraping: https://www.channelnewsasia.com/world/us-imposes-sweeping-sanctions-russia-targets-over-500-people-entities-4145251
# Scraping: https://www.channelnewsasia.com/world/eu-agrees-new-sanctions-against-russia-ahead-ukraine-war-anniversary-41394766
# Failed to fetch https://www.channelnewsasia.com/world/eu-agrees-new-sanctions-against-russia-ahead-ukraine-war-anniversary-41394766: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/eu-agrees-new-sanctions-against-russia-ahead-ukraine-war-anniversary-41394766
# Scraping: https://www.channelnewsasia.com/world/european-union-sanctions-19-myanmar-officials-froze-assets-3054551
# Scraping: https://www.channelnewsasia.com/world/eu-imposes-sanctions-human-rights-violations-ukraine-russia-and-other-countries-3643066
# Failed to fetch https://www.channelnewsasia.com/world/eu-imposes-sanctions-human-rights-violations-ukraine-russia-and-other-countries-3643066: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/eu-imposes-sanctions-human-rights-violations-ukraine-russia-and-other-countries-3643066
# Scraping: https://www.channelnewsasia.com/world/eu-targets-iran-over-protest-crackdown-russia-drone-sales-3139606
# Scraping: https://www.channelnewsasia.com/asia/chinese-app-tiktok-cuts-jobs-india-following-ban-441901
# Scraping: https://www.channelnewsasia.com/world/eu-sanctions-belarus-officials-lukashenko-729336
# Scraping: https://www.channelnewsasia.com/world/cuba-blames-us-rising-migrant-traffic-thru-central-america-3821536
# Failed to fetch https://www.channelnewsasia.com/world/cuba-blames-us-rising-migrant-traffic-thru-central-america-3821536: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/cuba-blames-us-rising-migrant-traffic-thru-central-america-3821536
# Scraping: https://www.channelnewsasia.com/world/us-issues-new-sanctions-against-top-russian-ally-belarus-3688336
# Failed to fetch https://www.channelnewsasia.com/world/us-issues-new-sanctions-against-top-russian-ally-belarus-3688336: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/us-issues-new-sanctions-against-top-russian-ally-belarus-3688336
# Scraping: https://www.channelnewsasia.com/world/us-sanctions-will-not-make-russia-stop-protecting-its-interests-russian-ambassador-4145586
# Scraping: https://www.channelnewsasia.com/asia/china-sanctions-lithuanian-deputy-minister-taiwan-visit-2877111
# Scraping: https://www.channelnewsasia.com/world/us-imposes-more-sanctions-money-lending-network-tied-yemens-houthi-rebels-4015071
# Scraping: https://www.channelnewsasia.com/world/navalnys-death-uk-sanctions-heads-russian-prison-4139081
# Scraping: https://www.channelnewsasia.com/commentary/singapore-sanctions-russia-ukraine-war-economic-impact-prices-petrol-electricity-2614031
# Scraping: https://www.channelnewsasia.com/asia/global-community-steps-financial-pressure-myanmar-military-junta-international-sanctions-singapore-bank-uob-3740016
# Scraping: https://www.channelnewsasia.com/world/us-expands-sanctions-myanmar-jet-fuel-cites-junta-airstrikes-3719476
# Failed to fetch https://www.channelnewsasia.com/world/us-expands-sanctions-myanmar-jet-fuel-cites-junta-airstrikes-3719476: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/us-expands-sanctions-myanmar-jet-fuel-cites-junta-airstrikes-3719476
# Scraping: https://www.channelnewsasia.com/business/north-korea-economy-shrank-third-year-2022-souths-central-bank-3660721
# Failed to fetch https://www.channelnewsasia.com/business/north-korea-economy-shrank-third-year-2022-souths-central-bank-3660721: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/north-korea-economy-shrank-third-year-2022-souths-central-bank-3660721
# Scraping: https://www.channelnewsasia.com/commentary/north-korea-kim-jong-un-covid-cases-food-shortage-trade-sanction-china-2132416
# Scraping: http://edition.cnn.com/2011/WORLD/asiapcf/09/06/israel.turkey/index.html
# Failed to fetch http://edition.cnn.com/2011/WORLD/asiapcf/09/06/israel.turkey/index.html: 404 Client Error: OK for url: https://edition.cnn.com/2011/WORLD/asiapcf/09/06/israel.turkey/index.html
# Scraping: https://www.channelnewsasia.com/asia/china-threatens-more-trade-sanctions-taiwan-election-nears-4012396
# Failed to fetch https://www.channelnewsasia.com/asia/china-threatens-more-trade-sanctions-taiwan-election-nears-4012396: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/china-threatens-more-trade-sanctions-taiwan-election-nears-4012396
# Scraping: https://www.channelnewsasia.com/asia/taiwan-apec-forum-offers-rare-chance-break-china-bonds-3922906
# Scraping: https://www.channelnewsasia.com/asia/hong-kongs-top-judge-defends-courts-amid-western-concerns-4065506
# Failed to fetch https://www.channelnewsasia.com/asia/hong-kongs-top-judge-defends-courts-amid-western-concerns-4065506: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/hong-kongs-top-judge-defends-courts-amid-western-concerns-4065506
# Scraping: https://www.channelnewsasia.com/singapore/russia-sanctions-evade-singapore-company-director-serena-ng-3252226
# Scraping: https://www.businesstimes.com.sg/international/australia-threatens-wto-action-china-hikes-duty-wine
# Scraping: https://www.channelnewsasia.com/world/united-states-sanctions-myanmar-defence-ministry-banks-arms-foreign-sources-3577926
# Failed to fetch https://www.channelnewsasia.com/world/united-states-sanctions-myanmar-defence-ministry-banks-arms-foreign-sources-3577926: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/united-states-sanctions-myanmar-defence-ministry-banks-arms-foreign-sources-3577926
# Scraping: https://www.channelnewsasia.com/world/venezuela-global-oil-stage-united-states-sanctions-world-energy-crunch-donald-trump-nicolas-maduro-russia-ukraine-3243131
# Scraping: https://www.channelnewsasia.com/asia/fukushima-radioactive-water-release-iaea-south-korea-japan-3616341
# Failed to fetch https://www.channelnewsasia.com/asia/fukushima-radioactive-water-release-iaea-south-korea-japan-3616341: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/fukushima-radioactive-water-release-iaea-south-korea-japan-3616341
# Scraping: https://www.channelnewsasia.com/world/russia-says-new-south-korean-sanctions-are-unfriendly-will-respond-4240326
# Scraping: https://www.channelnewsasia.com/asia/us-will-not-invite-sanctioned-hong-kong-leader-john-lee-apec-3663131
# Failed to fetch https://www.channelnewsasia.com/asia/us-will-not-invite-sanctioned-hong-kong-leader-john-lee-apec-3663131: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/us-will-not-invite-sanctioned-hong-kong-leader-john-lee-apec-3663131
# Scraping: https://www.channelnewsasia.com/business/sanctioned-china-stocks-win-sudden-boost-patriotic-buyers-3517131
# Failed to fetch https://www.channelnewsasia.com/business/sanctioned-china-stocks-win-sudden-boost-patriotic-buyers-3517131: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/sanctioned-china-stocks-win-sudden-boost-patriotic-buyers-3517131
# Scraping: https://www.channelnewsasia.com/asia/china-sanction-5-us-manufacturers-over-arms-sales-taiwan-4029751
# Failed to fetch https://www.channelnewsasia.com/asia/china-sanction-5-us-manufacturers-over-arms-sales-taiwan-4029751: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/china-sanction-5-us-manufacturers-over-arms-sales-taiwan-4029751
# Scraping: https://www.channelnewsasia.com/business/us-slaps-sanctions-greek-spyware-vendor-says-it-targeted-us-officials-4173541
# Scraping: https://www.channelnewsasia.com/commentary/us-airstrikes-iraq-syria-iran-jordan-attack-snap-insight-4096871
# Scraping: https://www.channelnewsasia.com/world/uk-and-us-sanction-senior-houthis-over-red-sea-shipping-attacks-4075036
# Failed to fetch https://www.channelnewsasia.com/world/uk-and-us-sanction-senior-houthis-over-red-sea-shipping-attacks-4075036: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/uk-and-us-sanction-senior-houthis-over-red-sea-shipping-attacks-4075036
# Scraping: https://www.channelnewsasia.com/business/exclusive-us-targets-chinas-top-chipmaking-plant-after-huawei-mate-60-pro-sources-say-4139131
# Scraping: https://www.channelnewsasia.com/business/taiwan-probes-four-firms-accused-helping-chinas-huawei-3825726
# Failed to fetch https://www.channelnewsasia.com/business/taiwan-probes-four-firms-accused-helping-chinas-huawei-3825726: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/taiwan-probes-four-firms-accused-helping-chinas-huawei-3825726
# Scraping: https://www.straitstimes.com/world/canada-sanctions-17-saudi-nationals-over-khashoggi-killing
# Scraping: https://www.channelnewsasia.com/world/china-pompeo-other-trump-officials-sanctions-424266
# Scraping: https://apnews.com/article/japan-south-north-korea-unification-minister-a399cb15715d827105563f279a9996e1#:~:text=In%202019%2C%20Japan%27s%20government%20tightened,restoring%20each%20other%27s%20trade%20status.
# Scraping: https://apnews.com/united-states-government-general-news-60bc85e527d0455eb6fd49d9535db185
# Scraping: https://edition.cnn.com/2019/05/02/india/masood-azhar-un-sanctions-intl/index.html
# Scraping: https://www.channelnewsasia.com/world/us-uk-unveil-sweeping-sanctions-iran-after-attack-israel-4275611
# Failed to fetch https://www.channelnewsasia.com/world/us-uk-unveil-sweeping-sanctions-iran-after-attack-israel-4275611: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/us-uk-unveil-sweeping-sanctions-iran-after-attack-israel-4275611
# Scraping: https://www.ctvnews.ca/politics/canada-sanctions-iranians-accused-of-violently-repressing-women-and-girls-1.6799720
# Scraping: https://www.channelnewsasia.com/world/hamas-funding-money-crypto-taxation-investments-israel-war-conflict-gaza-3911911
# Scraping: https://www.hrw.org/news/2024/02/06/australias-myanmar-sanctions-step-forward
# Scraping: https://www.bbc.com/news/uk-politics-68654533
# Scraping: https://www.bbc.com/news/uk-68274777
# Scraping: https://www.channelnewsasia.com/asia/us-sanctions-russian-entities-digital-currency-sanctions-evasion-4220806
# Scraping: https://www.channelnewsasia.com/world/us-weighing-tougher-sanctions-russia-2463461
# Scraping: https://uniglobalunion.org/news/sanctions-myanmar-state-owned-banks/
# Scraping: https://www.koreatimes.co.kr/www/nation/2024/04/103_367050.html
# Scraping: https://in-cyprus.philenews.com/international/eu-imposes-sanctions-against-violent-west-bank-settlers/
# Failed to fetch https://in-cyprus.philenews.com/international/eu-imposes-sanctions-against-violent-west-bank-settlers/: 403 Client Error: Forbidden for url: https://in-cyprus.philenews.com/international/eu-imposes-sanctions-against-violent-west-bank-settlers/
# Scraping: https://www.channelnewsasia.com/business/sechin-lauds-safety-russian-oil-sales-china-amid-chaos-middle-east-3857766
# Failed to fetch https://www.channelnewsasia.com/business/sechin-lauds-safety-russian-oil-sales-china-amid-chaos-middle-east-3857766: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/sechin-lauds-safety-russian-oil-sales-china-amid-chaos-middle-east-3857766
# Scraping: https://au.news.yahoo.com/canada-slaps-more-sanctions-belarus-151901047.html
# Scraping: https://www.channelnewsasia.com/business/samsung-pay-stop-working-russias-mir-payment-system-april-3-4225746
# Scraping: https://www.inqld.com.au/business/2024/02/27/chinese-sanctions-on-wine-worth-1-billion-to-be-lifted-by-end-of-month-minister
# Failed to fetch https://www.inqld.com.au/business/2024/02/27/chinese-sanctions-on-wine-worth-1-billion-to-be-lifted-by-end-of-month-minister: 403 Client Error: Forbidden for url: https://www.inqld.com.au/business/2024/02/27/chinese-sanctions-on-wine-worth-1-billion-to-be-lifted-by-end-of-month-minister
# Scraping: https://www.independent.co.ug/sudan-denounces-eu-sanctions-against-economic-institutions-as-unjust/
# Failed to fetch https://www.independent.co.ug/sudan-denounces-eu-sanctions-against-economic-institutions-as-unjust/: 403 Client Error: Forbidden for url: https://www.independent.co.ug/sudan-denounces-eu-sanctions-against-economic-institutions-as-unjust/
# Scraping: https://www.channelnewsasia.com/world/china-summons-foreign-diplomats-protest-sanctions-274581
# Scraping: https://www.channelnewsasia.com/world/eu-adds-russias-biggest-diamond-producer-alrosa-sanctions-list-4022721
# Failed to fetch https://www.channelnewsasia.com/world/eu-adds-russias-biggest-diamond-producer-alrosa-sanctions-list-4022721: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/eu-adds-russias-biggest-diamond-producer-alrosa-sanctions-list-4022721
# Scraping: https://www.channelnewsasia.com/business/chevron-hands-myanmar-gas-field-stake-junta-thailands-pttep-4252191
# Scraping: https://web.archive.org/web/20240331095538/https://www.channelnewsasia.com/world/israel-starvation-weapon-war-gaza-hamas-4205971
# Scraping: https://www.channelnewsasia.com/cna-insider/why-southeast-asia-should-worry-if-afghanistan-fails-terrorism-expert-2160036
# Scraping: https://www.channelnewsasia.com/commentary/ukraine-war-second-anniversary-russia-invasion-west-support-us-eu-nato-4144521
# Scraping: https://reliefweb.int/report/democratic-republic-congo/dr-congo-spotlight-equateur-crisis
# Scraping: https://www.channelnewsasia.com/commentary/taliban-press-conference-first-wants-world-trust-2122781
# Scraping: https://www.channelnewsasia.com/asia/exodus-thailand-continues-after-fall-key-myanmar-border-town-4260436
# Scraping: https://www.channelnewsasia.com/asia/asias-toughest-jobs-thai-border-patrol-soldier-who-risks-his-life-every-day-1008846
# Scraping: https://www.channelnewsasia.com/asia/thailand-myanmar-border-clashes-military-junta-4260386
# Failed to fetch https://www.channelnewsasia.com/asia/thailand-myanmar-border-clashes-military-junta-4260386: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/thailand-myanmar-border-clashes-military-junta-4260386
# Scraping: https://www.channelnewsasia.com/commentary/myanmar-civil-war-coup-opposition-resistance-ceasefire-4059991
# Scraping: https://www.channelnewsasia.com/world/sudan-war-rages-truce-extension-fighting-dead-injured-fled-3451596
# Failed to fetch https://www.channelnewsasia.com/world/sudan-war-rages-truce-extension-fighting-dead-injured-fled-3451596: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/sudan-war-rages-truce-extension-fighting-dead-injured-fled-3451596
# Scraping: https://www.channelnewsasia.com/world/millions-sudanese-go-hungry-war-disrupts-food-supply-4175496
# Scraping: https://www.hrw.org/world-report/2022/country-chapters/cameroon
# Scraping: https://www.channelnewsasia.com/world/russian-forces-appear-shift-siege-warfare-ukraine-us-official-2523711
# Scraping: https://www.theguardian.com/world/2010/may/24/gangs-barricade-kingston-jamaica
# Scraping: https://www.channelnewsasia.com/world/islamic-state-claims-responsibility-deadly-philippine-bombing-3963006
# Failed to fetch https://www.channelnewsasia.com/world/islamic-state-claims-responsibility-deadly-philippine-bombing-3963006: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/islamic-state-claims-responsibility-deadly-philippine-bombing-3963006
# Scraping: https://www.bbc.com/news/world-asia-67690614
# Scraping: https://www.channelnewsasia.com/asia/answer-marawi-extremism-seen-more-just-religion-994156
# Scraping: https://www.channelnewsasia.com/world/rise-mexican-cartel-violence-drives-record-migration-us-3991871
# Failed to fetch https://www.channelnewsasia.com/world/rise-mexican-cartel-violence-drives-record-migration-us-3991871: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/rise-mexican-cartel-violence-drives-record-migration-us-3991871
# Scraping: https://www.newsweek.com/nigeria-oil-yemi-osinbajo-niger-delta-629964
# Failed to fetch https://www.newsweek.com/nigeria-oil-yemi-osinbajo-niger-delta-629964: 403 Client Error: Forbidden for url: https://www.newsweek.com/nigeria-oil-yemi-osinbajo-niger-delta-629964
# Scraping: https://www.channelnewsasia.com/commentary/us-uk-houthi-strike-yemen-iran-gaza-war-international-law-4111146
# Scraping: https://www.newsweek.com/tompolo-niger-delta-avengers-nigeria-oil-616154
# Failed to fetch https://www.newsweek.com/tompolo-niger-delta-avengers-nigeria-oil-616154: 403 Client Error: Forbidden for url: https://www.newsweek.com/tompolo-niger-delta-avengers-nigeria-oil-616154
# Scraping: https://www.africanews.com/2024/03/07/at-least-10-people-killed-as-rebels-seize-a-town-in-congos-conflict-hit-eastern-region//
# Scraping: https://apnews.com/article/congo-north-kivu-ituri-goma-violence-conflict-tshisekedi-0c1990292498e65875cd7f989b65f641
# Scraping: https://www.channelnewsasia.com/world/us-strike-iraq-syria-retaliatory-jordan-attack-us-soldiers-iran-4096421
# Scraping: https://www.dw.com/en/dr-congo-conflict-pulls-in-more-players-to-tackle-rebels/a-68304390
# Scraping: https://www.africanews.com/2023/12/28/central-african-republic-peacekeepers-deployed-in-the-area-of-a-massacre-of-23-civilians//
# Scraping: https://www.channelnewsasia.com/world/united-states-forces-under-fire-middle-east-conflict-widens-3909331
# Failed to fetch https://www.channelnewsasia.com/world/united-states-forces-under-fire-middle-east-conflict-widens-3909331: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/united-states-forces-under-fire-middle-east-conflict-widens-3909331
# Scraping: https://www.channelnewsasia.com/world/us-sanctions-iran-targets-over-jordan-attack-4095701
# Scraping: https://www.channelnewsasia.com/world/israel-hamas-war-defence-minister-retaliatory-actions-iraq-yemen-iran-4011271
# Failed to fetch https://www.channelnewsasia.com/world/israel-hamas-war-defence-minister-retaliatory-actions-iraq-yemen-iran-4011271: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/israel-hamas-war-defence-minister-retaliatory-actions-iraq-yemen-iran-4011271
# Scraping: https://www.channelnewsasia.com/world/usa-invasion-iraq-20-years-anniversary-analysts-3359621
# Scraping: https://www.thenation.com/article/archive/central-african-republics-forgotten-crisis/
# Scraping: https://www.bbc.com/news/world-latin-america-63373068
# Scraping: https://www.channelnewsasia.com/world/iraq-armed-groups-united-states-iran-islamic-state-attacks-jordan-response-dial-down-esmil-qaani-baghdad-4132306
# Scraping: https://www.nytimes.com/2013/11/14/world/americas/guerrillas-step-up-campaign-in-paraguay.html
# Failed to fetch https://www.nytimes.com/2013/11/14/world/americas/guerrillas-step-up-campaign-in-paraguay.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2013/11/14/world/americas/guerrillas-step-up-campaign-in-paraguay.html
# Scraping: https://www.nbcnews.com/id/wbna22962528
# Scraping: https://www.channelnewsasia.com/world/bomb-attack-targets-turkish-capital-kurdish-militants-claim-responsibility-3812276
# Failed to fetch https://www.channelnewsasia.com/world/bomb-attack-targets-turkish-capital-kurdish-militants-claim-responsibility-3812276: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/bomb-attack-targets-turkish-capital-kurdish-militants-claim-responsibility-3812276
# Scraping: https://www.theguardian.com/global/2008/jul/28/kenya.humanrights
# Scraping: https://www.theguardian.com/world/2019/aug/30/east-timor-indonesias-invasion-and-the-long-road-to-independence
# Scraping: https://www.sundaytimes.lk/090524/News/sundaytimesnews_24.html
# Failed to fetch https://www.sundaytimes.lk/090524/News/sundaytimesnews_24.html: 403 Client Error: Forbidden for url: https://www.sundaytimes.lk/090524/News/sundaytimesnews_24.html
# Scraping: https://www.nytimes.com/2024/02/27/world/africa/somalia-ethiopia-al-shabab-conflict.html
# Failed to fetch https://www.nytimes.com/2024/02/27/world/africa/somalia-ethiopia-al-shabab-conflict.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2024/02/27/world/africa/somalia-ethiopia-al-shabab-conflict.html
# Scraping: https://www.africanews.com/2024/01/24/civil-war-turned-somalias-main-soccer-stadium-into-an-army-camp-now-its-hosting-games-agai//
# Scraping: https://www.aljazeera.com/news/2023/9/12/tuareg-rebels-claim-control-of-northern-mali-town-after-weeks-of-fighting
# Scraping: https://www.channelnewsasia.com/world/yemens-houthis-claim-attack-norwegian-tanker-strinda-red-sea-israel-hamas-war-3983261
# Failed to fetch https://www.channelnewsasia.com/world/yemens-houthis-claim-attack-norwegian-tanker-strinda-red-sea-israel-hamas-war-3983261: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/yemens-houthis-claim-attack-norwegian-tanker-strinda-red-sea-israel-hamas-war-3983261
# Scraping: https://www.theguardian.com/world/2007/sep/03/syria.lebanon
# Scraping: https://www.theguardian.com/world/2007/may/22/syria.topstories3
# Scraping: https://www.channelnewsasia.com/world/biden-recognises-armenian-genocide-defying-turkey-watershed-244836
# Failed to fetch https://www.channelnewsasia.com/world/biden-recognises-armenian-genocide-defying-turkey-watershed-244836: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/biden-recognises-armenian-genocide-defying-turkey-watershed-244836
# Scraping: https://www.channelnewsasia.com/world/al-shabaab-un-helicopter-militants-capture-4038336
# Failed to fetch https://www.channelnewsasia.com/world/al-shabaab-un-helicopter-militants-capture-4038336: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/al-shabaab-un-helicopter-militants-capture-4038336
# Scraping: https://www.channelnewsasia.com/world/why-are-120000-people-about-move-nagorno-karabakh-3795051
# Failed to fetch https://www.channelnewsasia.com/world/why-are-120000-people-about-move-nagorno-karabakh-3795051: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/why-are-120000-people-about-move-nagorno-karabakh-3795051
# Scraping: https://www.channelnewsasia.com/world/azerbaijan-halts-karabakh-offensive-after-ceasefire-deal-armenian-separatists-3786306
# Failed to fetch https://www.channelnewsasia.com/world/azerbaijan-halts-karabakh-offensive-after-ceasefire-deal-armenian-separatists-3786306: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/azerbaijan-halts-karabakh-offensive-after-ceasefire-deal-armenian-separatists-3786306
# Scraping: https://www.nbcnews.com/id/wbna23787141
# Scraping: https://www.aljazeera.com/news/2011/4/27/ceasefire-follows-thai-cambodia-border-clash
# Scraping: https://www.channelnewsasia.com/world/russia-vladimir-putin-ukraine-war-kyiv-deal-special-military-operation-3988956
# Failed to fetch https://www.channelnewsasia.com/world/russia-vladimir-putin-ukraine-war-kyiv-deal-special-military-operation-3988956: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/russia-vladimir-putin-ukraine-war-kyiv-deal-special-military-operation-3988956
# Scraping: https://www.bbc.com/news/world-africa-40340210
# Scraping: https://www.irishtimes.com/news/bangladesh-guards-die-in-india-border-clash-1.826096
# Scraping: https://www.channelnewsasia.com/asia/malaysia-pm-anwar-stresses-importance-peace-development-during-thailand-visit-3266566
# Scraping: https://www.channelnewsasia.com/world/france-pull-troops-out-niger-following-coup-3795581
# Failed to fetch https://www.channelnewsasia.com/world/france-pull-troops-out-niger-following-coup-3795581: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/france-pull-troops-out-niger-following-coup-3795581
# Scraping: https://www.channelnewsasia.com/asia/north-korea-hypersonic-missiles-stronger-action-us-sanction-2434856
# Scraping: https://www.reuters.com/business/environment/environmental-group-criticises-italys-eni-use-palm-oil-by-product-2024-01-29/
# Failed to fetch https://www.reuters.com/business/environment/environmental-group-criticises-italys-eni-use-palm-oil-by-product-2024-01-29/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/business/environment/environmental-group-criticises-italys-eni-use-palm-oil-by-product-2024-01-29/
# Scraping: https://www.reuters.com/markets/asia/ex-boj-board-member-criticises-governor-uedas-market-messaging-2023-12-26/
# Failed to fetch https://www.reuters.com/markets/asia/ex-boj-board-member-criticises-governor-uedas-market-messaging-2023-12-26/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/markets/asia/ex-boj-board-member-criticises-governor-uedas-market-messaging-2023-12-26/
# Scraping: https://www.channelnewsasia.com/sport/appointment-criticised-referee-be-welcomed-both-england-and-sa-says-erasmus-3853581
# Failed to fetch https://www.channelnewsasia.com/sport/appointment-criticised-referee-be-welcomed-both-england-and-sa-says-erasmus-3853581: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/sport/appointment-criticised-referee-be-welcomed-both-england-and-sa-says-erasmus-3853581
# Scraping: https://www.reuters.com/sustainability/society-equity/indonesias-astra-agro-criticised-by-green-groups-over-report-grievances-2023-11-27/
# Failed to fetch https://www.reuters.com/sustainability/society-equity/indonesias-astra-agro-criticised-by-green-groups-over-report-grievances-2023-11-27/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/sustainability/society-equity/indonesias-astra-agro-criticised-by-green-groups-over-report-grievances-2023-11-27/
# Scraping: https://www.reuters.com/world/middle-east/activists-criticise-civil-society-restrictions-wto-meeting-uae-2024-02-28/
# Failed to fetch https://www.reuters.com/world/middle-east/activists-criticise-civil-society-restrictions-wto-meeting-uae-2024-02-28/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/world/middle-east/activists-criticise-civil-society-restrictions-wto-meeting-uae-2024-02-28/
# Scraping: https://www.reuters.com/markets/europe/berlusconis-daughter-criticises-meloni-over-bank-windfall-tax-2023-09-15/
# Failed to fetch https://www.reuters.com/markets/europe/berlusconis-daughter-criticises-meloni-over-bank-windfall-tax-2023-09-15/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/markets/europe/berlusconis-daughter-criticises-meloni-over-bank-windfall-tax-2023-09-15/
# Scraping: https://www.channelnewsasia.com/world/us-senator-schumer-calls-new-elections-israel-criticises-netanyahu-4195786
# Scraping: https://www.channelnewsasia.com/singapore/facebook-meta-criticised-not-doing-enough-fight-scams-sun-xueling-4158831
# Scraping: https://www.straitstimes.com/singapore/amoy-st-restaurant-apologises-after-italy-s-ambassador-to-singapore-criticises-its-mafia-themed-night
# Scraping: https://www.straitstimes.com/world/europe/european-officials-criticize-trumps-nato-comments
# Scraping: https://www.channelnewsasia.com/asia/china-slams-foreign-criticism-upcoming-hong-kongs-article-23-national-security-law-4159561
# Scraping: https://www.channelnewsasia.com/world/turkiyes-erdogan-braces-meeting-biden-may-4230566
# Failed to fetch https://www.channelnewsasia.com/world/turkiyes-erdogan-braces-meeting-biden-may-4230566: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/turkiyes-erdogan-braces-meeting-biden-may-4230566
# Scraping: https://www.nytimes.com/2024/01/19/world/asia/thailand-sentence-royalty-defamation.html
# Failed to fetch https://www.nytimes.com/2024/01/19/world/asia/thailand-sentence-royalty-defamation.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2024/01/19/world/asia/thailand-sentence-royalty-defamation.html
# Scraping: https://www.bbc.com/sport/football/68859437
# Scraping: https://www.bbc.com/travel/article/20240213-taylor-swift-private-jet-flight-travel-carbon-footprint
# Scraping: https://www.nytimes.com/2023/11/02/business/media/microsoft-guardian-ai-poll.html
# Failed to fetch https://www.nytimes.com/2023/11/02/business/media/microsoft-guardian-ai-poll.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2023/11/02/business/media/microsoft-guardian-ai-poll.html
# Scraping: https://www.washingtonpost.com/style/media/2023/11/17/mona-chalabi-gaza-criticize-new-york-times-pulitzer/
# Failed to fetch https://www.washingtonpost.com/style/media/2023/11/17/mona-chalabi-gaza-criticize-new-york-times-pulitzer/: HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=10)
# Scraping: https://www.nytimes.com/2023/10/11/us/politics/trump-netanyahu-israel.html
# Failed to fetch https://www.nytimes.com/2023/10/11/us/politics/trump-netanyahu-israel.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2023/10/11/us/politics/trump-netanyahu-israel.html
# Scraping: https://www.nytimes.com/2023/06/28/arts/design/moms-liberty-museum-american-revolution.html
# Failed to fetch https://www.nytimes.com/2023/06/28/arts/design/moms-liberty-museum-american-revolution.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2023/06/28/arts/design/moms-liberty-museum-american-revolution.html
# Scraping: https://www.channelnewsasia.com/business/ex-boj-board-member-criticises-governor-uedas-market-messaging-4010691
# Failed to fetch https://www.channelnewsasia.com/business/ex-boj-board-member-criticises-governor-uedas-market-messaging-4010691: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/ex-boj-board-member-criticises-governor-uedas-market-messaging-4010691
# Scraping: https://www.channelnewsasia.com/world/auschwitz-memorial-criticises-musks-x-not-removing-antisemitic-content-3706281
# Failed to fetch https://www.channelnewsasia.com/world/auschwitz-memorial-criticises-musks-x-not-removing-antisemitic-content-3706281: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/auschwitz-memorial-criticises-musks-x-not-removing-antisemitic-content-3706281
# Scraping: https://www.independent.co.uk/tech/chatbot-swears-ai-dpd-poem-b2481967.html
# Failed to fetch https://www.independent.co.uk/tech/chatbot-swears-ai-dpd-poem-b2481967.html: 405 Client Error: Not allowed. for url: https://www.independent.co.uk/tech/chatbot-swears-ai-dpd-poem-b2481967.html
# Scraping: https://www.channelnewsasia.com/world/turkiye-condemns-israel-jenin-raid-calls-accountability-3991211
# Failed to fetch https://www.channelnewsasia.com/world/turkiye-condemns-israel-jenin-raid-calls-accountability-3991211: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/turkiye-condemns-israel-jenin-raid-calls-accountability-3991211
# Scraping: https://www.channelnewsasia.com/asia/japan-second-kobayashi-factory-inspected-deaths-beni-koji-4232891
# Scraping: https://www.channelnewsasia.com/business/amazon-latest-criticise-microsoft-uk-cloud-market-probe-3967196
# Failed to fetch https://www.channelnewsasia.com/business/amazon-latest-criticise-microsoft-uk-cloud-market-probe-3967196: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/amazon-latest-criticise-microsoft-uk-cloud-market-probe-3967196
# Scraping: https://www.channelnewsasia.com/singapore/cordlife-cord-blood-parents-upset-moh-investigation-3958866
# Scraping: https://www.channelnewsasia.com/world/western-officials-criticise-trumps-nato-comments-4116956
# Scraping: https://www.channelnewsasia.com/sport/israels-fa-president-zuares-criticises-wembley-arch-decision-3845286
# Failed to fetch https://www.channelnewsasia.com/sport/israels-fa-president-zuares-criticises-wembley-arch-decision-3845286: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/sport/israels-fa-president-zuares-criticises-wembley-arch-decision-3845286
# Scraping: https://www.channelnewsasia.com/asia/malaysia-swatch-lgbtq-watches-jail-fine-owners-ban-3690551
# Scraping: https://www.channelnewsasia.com/world/german-minister-criticises-vatican-stance-gay-couples-2120536
# Scraping: https://www.channelnewsasia.com/singapore/ocbc-scam-should-have-responded-faster-sms-phishing-lawrence-wong-2498936
# Scraping: https://www.channelnewsasia.com/world/croatia-criticises-nato-after-crash-russian-made-drone-2560201
# Scraping: https://www.straitstimes.com/life/arts/singapore-theatre-company-walks-back-name-change-after-theatre-community-protests
# Scraping: https://www.straitstimes.com/asia/se-asia/airasia-boss-tony-fernandes-criticised-for-holding-shirtless-online-call
# Scraping: https://www.straitstimes.com/asia/south-asia/google-agrees-to-restore-deleted-indian-apps-it-minister-says
# Scraping: https://www.straitstimes.com/asia/image-of-pigtailed-apple-customer-service-employee-upsets-chinese-netizens
# Scraping: https://www.straitstimes.com/sport/football/aston-villa-supporters-criticise-clubs-sponsorship-deal-with-betting-firm
# Scraping: https://www.channelnewsasia.com/asia/malaysia-johor-election-pejuang-anwar-not-uniting-opposition-2525386
# Scraping: https://cnalifestyle.channelnewsasia.com/entertainment/prince-william-criticises-space-tourism-over-need-repair-earth-284876
# Scraping: https://www.straitstimes.com/life/actor-daniel-wu-criticises-barbie-maker-mattel-for-playing-to-asian-stereotype
# Scraping: https://cnalifestyle.channelnewsasia.com/entertainment/the-weeknd-criticises-grammys-over-nominations-snub-187721
# Scraping: https://www.straitstimes.com/asia/east-asia/cathay-pacific-apologises-sacks-flight-crew-for-making-fun-of-passengers-for-their-english
# Scraping: https://www.straitstimes.com/singapore/pofma-office-directs-opposition-member-brad-bowyer-to-add-correction-notice-to-facebook
# Scraping: https://www.straitstimes.com/asia/east-asia/hm-blasted-on-chinese-social-media-for-pulling-xinjiang-cotton
# Scraping: https://www.straitstimes.com/lifestyle/entertainment/hong-kong-singer-shirley-kwan-quits-show-business
# Failed to fetch https://www.straitstimes.com/lifestyle/entertainment/hong-kong-singer-shirley-kwan-quits-show-business: 403 Client Error: Forbidden for url: https://www.straitstimes.com/lifestyle/entertainment/hong-kong-singer-shirley-kwan-quits-show-business
# Scraping: https://www.washingtonpost.com/technology/2024/02/05/meta-oversight-board-deepfake-president-biden/
# Failed to fetch https://www.washingtonpost.com/technology/2024/02/05/meta-oversight-board-deepfake-president-biden/: HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=10)
# Scraping: https://www.washingtonpost.com/climate-environment/2023/02/15/world-bank-president-climate-change/
# Failed to fetch https://www.washingtonpost.com/climate-environment/2023/02/15/world-bank-president-climate-change/: HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=10)
# Scraping: https://www.nytimes.com/2023/07/13/technology/ftc-lina-khan-hearing.html
# Failed to fetch https://www.nytimes.com/2023/07/13/technology/ftc-lina-khan-hearing.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2023/07/13/technology/ftc-lina-khan-hearing.html
# Scraping: https://www.nytimes.com/2023/05/07/business/media/texas-shooting-video-twitter.html
# Failed to fetch https://www.nytimes.com/2023/05/07/business/media/texas-shooting-video-twitter.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2023/05/07/business/media/texas-shooting-video-twitter.html
# Scraping: https://www.nytimes.com/2023/06/22/science/james-cameron-titanic-submersible.html
# Failed to fetch https://www.nytimes.com/2023/06/22/science/james-cameron-titanic-submersible.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2023/06/22/science/james-cameron-titanic-submersible.html
# Scraping: https://www.nytimes.com/2021/10/21/business/facebook-oversight-board-members-criticism.html
# Failed to fetch https://www.nytimes.com/2021/10/21/business/facebook-oversight-board-members-criticism.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2021/10/21/business/facebook-oversight-board-members-criticism.html
# Scraping: https://www.nytimes.com/2020/12/03/technology/google-researcher-timnit-gebru.html
# Failed to fetch https://www.nytimes.com/2020/12/03/technology/google-researcher-timnit-gebru.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2020/12/03/technology/google-researcher-timnit-gebru.html
# Scraping: https://www.nytimes.com/2020/11/06/technology/china-ant-group-ipo.html
# Failed to fetch https://www.nytimes.com/2020/11/06/technology/china-ant-group-ipo.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2020/11/06/technology/china-ant-group-ipo.html
# Scraping: https://www.nytimes.com/2020/11/10/business/amazon-eu-antitrust.html
# Failed to fetch https://www.nytimes.com/2020/11/10/business/amazon-eu-antitrust.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2020/11/10/business/amazon-eu-antitrust.html
# Scraping: https://www.nytimes.com/2018/01/08/business/hm-monkey.html
# Failed to fetch https://www.nytimes.com/2018/01/08/business/hm-monkey.html: 403 Client Error: Forbidden for url: https://www.nytimes.com/2018/01/08/business/hm-monkey.html
# Scraping: https://www.channelnewsasia.com/asia/taiwan-election-2024-presidential-candidates-cross-strait-foreign-policy-best-worst-case-scenarios-4015011
# Scraping: https://www.straitstimes.com/sport/olympians-criticise-nike-for-skimpy-womens-kit
# Scraping: https://www.channelnewsasia.com/business/chinese-firm-imported-copper-russian-controlled-part-ukraine-data-3417686
# ...
# Scraping: https://www.channelnewsasia.com/business/cathie-woods-ark-invests-bitcoin-futures-etf-sells-coinbase-shares-4014956
# Failed to fetch https://www.channelnewsasia.com/business/cathie-woods-ark-invests-bitcoin-futures-etf-sells-coinbase-shares-4014956: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/cathie-woods-ark-invests-bitcoin-futures-etf-sells-coinbase-shares-4014956
# Scraping: https://www.channelnewsasia.com/business/nb-renaissance-invests-app-developer-bending-spoons-eyes-ipo-3676251
# Failed to fetch https://www.channelnewsasia.com/business/nb-renaissance-invests-app-developer-bending-spoons-eyes-ipo-3676251: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/nb-renaissance-invests-app-developer-bending-spoons-eyes-ipo-3676251
# Scraping: https://www.channelnewsasia.com/business/jpmorgan-invests-financial-technology-provider-cleareyeai-3574076
# Failed to fetch https://www.channelnewsasia.com/business/jpmorgan-invests-financial-technology-provider-cleareyeai-3574076: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/jpmorgan-invests-financial-technology-provider-cleareyeai-3574076
# Scraping: https://www.straitstimes.com/business/temasek-in-talks-to-invest-in-openai-financial-times
# Scraping: https://www.bbc.com/news/business-48306172
# Scraping: https://www.bbc.com/sport/football/54069376
# Scraping: https://www.straitstimes.com/business/banking/ocbc-to-invest-30m-in-staff-development-over-3-years
# Scraping: https://www.straitstimes.com/business/gic-and-petronas-to-invest-in-green-ammonia-project-in-india
# Scraping: https://www.straitstimes.com/business/indonesia-says-exxonmobil-plans-to-invest-up-to-20-billion-in-the-country
# Scraping: https://www.bbc.com/news/business-18107508
# Scraping: https://www.straitstimes.com/business/ntt-says-to-test-driverless-vehicle-tech-with-toyota-invest-in-us-start-up
# Scraping: https://www.straitstimes.com/business/companies-markets/what-does-singapore-sovereign-wealth-fund-gic-invest-in
# Scraping: https://www.straitstimes.com/business/gic-to-invest-14b-in-european-renewable-energy-firm-edpr
# Scraping: https://www.channelnewsasia.com/business/microsoft-launches-lightweight-ai-model-4285606
# Scraping: https://www.bbc.com/news/business-34694935
# Scraping: https://www.channelnewsasia.com/business/exclusive-microsofts-openai-partnership-could-face-eu-antitrust-probe-sources-say-4275851
# Scraping: https://www.straitstimes.com/business/us-investment-firm-stonepeak-to-invest-in-singapore-headquartered-agp-sustainable-real-assets
# Scraping: https://www.bbc.com/news/business-44645569
# Scraping: https://www.channelnewsasia.com/business/eu-yan-sang-tcm-chinese-medicine-mitsui-rohto-4242546
# Scraping: https://www.channelnewsasia.com/business/twilio-appoints-sachem-head-partner-andy-stafman-board-4234661
# Scraping: https://www.straitstimes.com/business/companies-markets/amazon-steps-up-ai-race-with-up-to-us4-billion-deal-to-invest-in-anthropic
# Scraping: https://www.channelnewsasia.com/business/anthropic-weighs-slate-sovereign-wealth-funds-acquire-ftxs-1-billion-stake-cnbc-reports-4216111
# Scraping: https://www.straitstimes.com/business/companies-markets/singapores-jungle-ventures-raises-327m-for-third-fund-to-invest-in-south
# Scraping: https://www.channelnewsasia.com/business/microsoft-singles-out-googles-competitive-edge-generative-ai-4196136
# Scraping: https://www.channelnewsasia.com/business/temasek-holdings-invest-open-ai-singapore-4173066
# Scraping: https://www.channelnewsasia.com/business/israels-ourcrowd-ai-fund-fast-track-startups-nvidia-programme-4173196
# Scraping: https://www.channelnewsasia.com/business/france-had-no-prior-knowledge-microsofts-mistral-ai-deal-official-says-4156606
# Scraping: https://www.bbc.com/news/uk-scotland-scotland-business-33442922
# Scraping: https://www.straitstimes.com/business/companies-markets/uber-ceo-temasek-invest-in-urban-farming-start-up-bowery
# Scraping: https://www.channelnewsasia.com/business/crypto-exchange-ftx-sell-shares-ai-startup-anthropic-4143176
# Scraping: https://www.bbc.com/news/uk-scotland-scotland-business-35111702
# Scraping: https://www.straitstimes.com/uncategorized/toyotas-us1b-investment-in-grab-is-credit-positive-for-both-moodys
# Failed to fetch https://www.straitstimes.com/uncategorized/toyotas-us1b-investment-in-grab-is-credit-positive-for-both-moodys: 403 Client Error: Forbidden for url: https://www.straitstimes.com/uncategorized/toyotas-us1b-investment-in-grab-is-credit-positive-for-both-moodys
# Scraping: https://www.straitstimes.com/business/economy/temasek-google-to-invest-us350-million-in-indonesias-tokopedia
# Scraping: https://www.channelnewsasia.com/business/ai-firms-surge-after-chip-giant-nvidia-discloses-stake-4126031
# Scraping: https://www.straitstimes.com/business/invest/gic-temasek-participate-in-ant-financials-us14b-series-c-funding-round
# Scraping: https://www.straitstimes.com/business/companies-markets/cdl-to-invest-41m-in-property-service-provider-e-houses-hong-kong-ipo
# Scraping: https://www.straitstimes.com/business/companies-markets/temasek-edbi-invest-in-social-media-marketing-firm-sprinklr
# Scraping: https://www.straitstimes.com/business/singapore-press-holdings-enters-into-joint-venture-to-invest-in-han-language-centre
# Scraping: https://www.straitstimes.com/business/property/s-pore-s-thriving-property-market-drives-investor-interest-in-real-estate-tokens
# Scraping: https://www.straitstimes.com/business/gic-to-invest-643m-in-south-korea-s-kakao-entertainment-report
# Scraping: https://www.straitstimes.com/asia/se-asia/walmarts-partner-ribbit-capital-invests-in-bank-jago-indonesias-first-full-digital-bank
# Scraping: https://www.channelnewsasia.com/sport/real-goalkeeper-courtois-suffers-new-knee-injury-training-4206596
# Scraping: https://www.straitstimes.com/singapore/why-dialysis-may-not-be-a-good-option-for-some-kidney-failure-patients
# Scraping: https://www.channelnewsasia.com/sport/atletico-defender-gimenez-suffers-another-thigh-injury-4143646
# Scraping: https://cnalifestyle.channelnewsasia.com/entertainment/mark-ruffalo-opens-about-brain-tumour-diagnosis-23-years-ago-383731
# Scraping: https://www.channelnewsasia.com/singapore/man-bomb-hoax-scoot-flight-perth-relapse-schizophrenia-jail-4006756
# Scraping: https://www.channelnewsasia.com/sport/lutons-lockyer-suffers-cardiac-arrest-match-abandoned-city-drop-points-3994136
# Failed to fetch https://www.channelnewsasia.com/sport/lutons-lockyer-suffers-cardiac-arrest-match-abandoned-city-drop-points-3994136: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/sport/lutons-lockyer-suffers-cardiac-arrest-match-abandoned-city-drop-points-3994136
# Scraping: https://www.channelnewsasia.com/sport/former-conmebol-president-napout-be-released-us-jail-says-lawyer-3596496
# Failed to fetch https://www.channelnewsasia.com/sport/former-conmebol-president-napout-be-released-us-jail-says-lawyer-3596496: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/sport/former-conmebol-president-napout-be-released-us-jail-says-lawyer-3596496
# Scraping: https://www.straitstimes.com/singapore/19-year-old-in-constant-pain-but-is-all-smiles-as-she-shares-about-her-8-chronic-conditions-on-tiktok
# Scraping: https://www.channelnewsasia.com/singapore/court-woman-sues-brother-toa-payoh-flat-mother-dementia-sale-proceeds-equal-3531116
# Scraping: https://www.channelnewsasia.com/world/australian-sydney-grandmother-95-year-old-tasered-police-critical-condition-3500061
# Failed to fetch https://www.channelnewsasia.com/world/australian-sydney-grandmother-95-year-old-tasered-police-critical-condition-3500061: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/australian-sydney-grandmother-95-year-old-tasered-police-critical-condition-3500061
# Scraping: https://www.straitstimes.com/singapore/tiktok-trolls-pose-as-imh-doctors-in-concerning-social-media-trend
# Scraping: https://edition.cnn.com/2024/03/22/health/demon-faces-prosopometamorphopsia-wellness/index.html
# Scraping: https://edition.cnn.com/2024/03/17/entertainment/celine-dion-stiff-person-syndrome-three-sons/index.html
# Scraping: https://www.straitstimes.com/singapore/caregiver-support-network-expands-to-5-areas-including-eunos-and-chong-pang
# Scraping: https://edition.cnn.com/2023/07/12/entertainment/rob-mcelhenney-diagnosed-health-wellness/index.html
# Scraping: https://edition.cnn.com/2022/06/03/politics/john-fetterman-health/index.html
# Scraping: https://edition.cnn.com/2022/03/30/entertainment/bruce-willis-aphasia/index.html
# Scraping: https://www.straitstimes.com/asia/east-asia/south-korean-man-seeking-a-dignified-exit-from-pain-challenges-local-laws-criminalising-assisted-death
# Scraping: https://edition.cnn.com/2023/10/23/entertainment/jeremy-renner-accident-health/index.html
# Scraping: https://edition.cnn.com/2023/02/17/health/clinical-depression-explainer-wellness/index.html
# Scraping: https://edition.cnn.com/2021/11/03/entertainment/dean-winters-pain-amputations/index.html
# Scraping: https://www.straitstimes.com/sport/football/villas-kamara-suffers-significant-knee-ligament-injury
# Scraping: https://www.straitstimes.com/world/turkish-mp-dies-after-suffering-heart-attack-in-parliament
# Scraping: https://www.straitstimes.com/asia/se-asia/malaysian-boy-8-suffers-burns-on-his-body-after-struck-by-lightning
# Scraping: https://www.straitstimes.com/world/while-you-were-sleeping-5-stories-you-might-have-missed-march-20-5
# Scraping: https://www.straitstimes.com/singapore/no-one-has-helped-us-so-much-before-says-sole-caregiver-of-ailing-husband-and-son-with-autism
# Scraping: https://www.straitstimes.com/singapore/toddler-with-rare-genetic-condition-to-receive-treatment-after-2-mil-crowdfunding-and-drug-getting-registered
# Scraping: https://www.straitstimes.com/life/entertainment/actor-shawn-yue-reveals-he-suffered-from-panic-disorder-for-six-years
# Scraping: https://www.straitstimes.com/singapore/s-porean-student-suffers-fractured-cheekbone-memory-loss-after-crashing-atv-against-tree-in-bali
# Scraping: https://www.straitstimes.com/life/entertainment/singer-jessie-j-gives-birth-to-first-child-after-suffering-a-miscarriage-in-2021
# Scraping: https://www.straitstimes.com/world/europe/italy-grants-citizenship-to-baby-girl-in-britain-to-prevent-weaning-off-life-support
# Scraping: https://www.straitstimes.com/singapore/community/age-taking-toll-as-72-year-old-cares-for-father-99-who-has-dementia
# Scraping: https://www.straitstimes.com/lifestyle/entertainment/hong-kong-actor-law-kar-ying-suffers-from-urinary-incontinence-after
# Failed to fetch https://www.straitstimes.com/lifestyle/entertainment/hong-kong-actor-law-kar-ying-suffers-from-urinary-incontinence-after: 403 Client Error: Forbidden for url: https://www.straitstimes.com/lifestyle/entertainment/hong-kong-actor-law-kar-ying-suffers-from-urinary-incontinence-after
# Scraping: https://www.bbc.com/news/articles/c720lrd0xpzo
# Scraping: https://www.bbc.com/sport/football/68279260
# Scraping: https://www.bbc.com/sport/football/68276779
# Scraping: https://www.bbc.com/news/articles/cx7zq169dqlo
# Scraping: https://www.channelnewsasia.com/world/britains-duchess-york-diagnosed-skin-cancer-4063991
# Failed to fetch https://www.channelnewsasia.com/world/britains-duchess-york-diagnosed-skin-cancer-4063991: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/britains-duchess-york-diagnosed-skin-cancer-4063991
# Scraping: https://www.straitstimes.com/sport/are-you-remorseful-gymnast-asks-sex-abuse-gymnastics-doctor-larry-nassar
# Scraping: https://www.straitstimes.com/singapore/singapore-airlines-to-review-serving-nuts-on-its-flights-after-toddler-has-allergic
# Scraping: https://www.straitstimes.com/sport/hockey-player-suffers-stroke-after-collision
# Scraping: https://www.straitstimes.com/life/entertainment/kim-kardashian-urges-quick-divorce-from-kanye-west
# Scraping: https://www.scmp.com/news/people-culture/trending-china/article/3254492/kickboxing-china-phd-student-prestigious-canadian-university-suffers-brain-damage-brutal-combat
# Scraping: https://www.straitstimes.com/lifestyle/entertainment/actor-lee-kin-yan-known-for-playing-ru-hua-in-stephen-chows-movies-suffers
# Failed to fetch https://www.straitstimes.com/lifestyle/entertainment/actor-lee-kin-yan-known-for-playing-ru-hua-in-stephen-chows-movies-suffers: 403 Client Error: Forbidden for url: https://www.straitstimes.com/lifestyle/entertainment/actor-lee-kin-yan-known-for-playing-ru-hua-in-stephen-chows-movies-suffers
# Scraping: https://www.straitstimes.com/lifestyle/entertainment/movie-review-mental-health-issues-hog-the-road-within
# Failed to fetch https://www.straitstimes.com/lifestyle/entertainment/movie-review-mental-health-issues-hog-the-road-within: 403 Client Error: Forbidden for url: https://www.straitstimes.com/lifestyle/entertainment/movie-review-mental-health-issues-hog-the-road-within
# Scraping: https://www.straitstimes.com/singapore/health/caregivers-recognised-for-contributions-to-society-in-biennial-awards
# Scraping: https://www.straitstimes.com/singapore/courts-crime/nearly-3-years-jail-for-man-who-used-fake-1000-note-to-buy-cough-syrup-and-sleeping-pills
# Scraping: https://www.straitstimes.com/world/family-of-beach-boys-mastermind-brian-wilson-seeks-conservatorship-for-him
# Scraping: https://www.scmp.com/lifestyle/health-wellness/article/3255223/can-running-keep-diabetes-check-finance-exec-took-sport-avoid-taking-medication-condition-now-he
# Scraping: https://www.channelnewsasia.com/singapore/young-adults-battling-cancer-lonely-journey-big-read-3775741
# Scraping: https://www.nuhsplus.edu.sg/article/overcoming-the-odds-living-with-jia
# Scraping: https://www.nuhsplus.edu.sg/article/screening-tool-may-enable-early-detection-of-autism-in-young-children
# Scraping: https://www.nuhsplus.edu.sg/article/when-menopause-isn-t-smooth-sailing
# Scraping: https://www.nuhsplus.edu.sg/article/hope-for-patients-with-stage-4-colorectal-cancer
# Scraping: https://www.nuhsplus.edu.sg/article/mother-with-kidney-failure-defies-the-odds-to-give-birth
# Scraping: https://www.channelnewsasia.com/singapore/what-postpartum-depression-how-seek-help-kkh-3605126
# Scraping: https://www.nuhsplus.edu.sg/article/providing-golden-care-for-patients-in-their-golden-years
# Scraping: https://cnalifestyle.channelnewsasia.com/entertainment/nick-shen-shingles-371086
# Scraping: https://www.channelnewsasia.com/singapore/iris-koh-apply-leave-singapore-malaysia-cancer-medical-treatment-bail-2752671
# Scraping: https://www.channelnewsasia.com/singapore/sammyboy-sex-forum-role-illegal-activity-photos-videos-difficult-shut-down-3230171
# Scraping: https://www.channelnewsasia.com/asia/vietnam-tet-dong-tao-chicken-dragon-chicken-bigfoot-chicken-delicacy-4109931
# Scraping: https://www.channelnewsasia.com/business/genome-study-reveals-prehistoric-ethiopian-origins-coffee-4269726
# Scraping: https://www.channelnewsasia.com/business/us-says-it-and-partners-have-taken-down-notorious-qakbot-hacking-network-3732981
# Failed to fetch https://www.channelnewsasia.com/business/us-says-it-and-partners-have-taken-down-notorious-qakbot-hacking-network-3732981: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/us-says-it-and-partners-have-taken-down-notorious-qakbot-hacking-network-3732981
# Scraping: https://www.channelnewsasia.com/singapore/singapore-subway-officially-certified-halal-no-pork-807306
# Scraping: https://www.channelnewsasia.com/commentary/key-commodities-affected-war-ukraine-natural-gas-energy-food-transport-microchips-2519171
# Scraping: https://www.channelnewsasia.com/singapore/trishaws-singapore-origins-history-timeline-transport-decline-4260826
# Scraping: https://edition.cnn.com/travel/article/essential-spanish-dishes/index.html
# Scraping: https://edition.cnn.com/travel/article/why-italys-gianduiotto-chocolate-rules/index.html
# country_network_scrape.html

# %%
# VERSION 2

## the country_network_optimized_vr4 is >= 4

import requests
from bs4 import BeautifulSoup
import spacy
import pycountry
import re
from collections import defaultdict
from transformers import pipeline, AutoTokenizer
from pyvis.network import Network
import pandas as pd
import math
import pycountry_convert as pc 

# Load SpaCy NLP model
nlp = spacy.load("en_core_web_sm")

# Load Hugging Face Transformers Sentiment Model
sentiment_pipeline = pipeline('sentiment-analysis', model='distilbert-base-uncased-finetuned-sst-2-english')

# Load tokenizer for accurate splitting
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")

class CountrySentimentAnalyzer:
    def __init__(self):                           
        """Initialize the text analyzer with NLP and data structures."""
        self.nlp = nlp  # Use loaded SpaCy model
        self.entities = defaultdict(set)
        self.relationships = []
        self.country_mentions = defaultdict(int)  # Track how often a country appears

    def clean_text(self, text):
        """Remove special characters, boilerplate content, and extra whitespace."""
        text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
        text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove special characters & numbers
        return text.strip()

    def standardize_country_name(self, country):
        """Attempt to standardize country names using pycountry."""
        try:
            return pycountry.countries.lookup(country).name
        except LookupError:
            return None  # Ignore non-country entities

    def get_sentiment(self, sentence):
        """Analyze sentiment while handling long sentences (Max: 512 tokens)."""
        max_length = 512  # Model token limit
        
        # Tokenize the sentence
        tokens = tokenizer.tokenize(sentence)
        
        # If the tokenized input is too long, split into chunks
        if len(tokens) > max_length:
            chunks = [" ".join(tokenizer.convert_tokens_to_string(tokens[i:i + max_length])) 
                      for i in range(0, len(tokens), max_length)]
        else:
            chunks = [sentence]  # Use original if within limit
    
        # Analyze sentiment for each chunk separately
        sentiments = []
        for chunk in chunks:
            try:
                result = sentiment_pipeline(chunk)
                sentiments.append(result[0]['label'])
            except RuntimeError as e:
                print(f"Error processing chunk: {e}")
                return "NEUTRAL"  # Default to NEUTRAL if there's an error
    
        # Aggregate sentiment from all chunks
        positive_count = sentiments.count("POSITIVE")
        negative_count = sentiments.count("NEGATIVE")
    
        if positive_count > negative_count:
            return "POSITIVE"
        elif negative_count > positive_count:
            return "NEGATIVE"
        else:
            return "NEUTRAL"

    def extract_entities_and_relationships(self, text, source=None):
        """Extract country entities (GPE) and relationships from text."""
        cleaned_text = self.clean_text(text)
        doc = self.nlp(cleaned_text)
        country_entities = set()

        for ent in doc.ents:
            if ent.label_ == "GPE":
                country_name = self.standardize_country_name(ent.text)
                if country_name:  # Only add valid countries
                    country_entities.add(country_name)
                    self.country_mentions[country_name] += 1  # Track country frequency

        # Store valid countries
        for country in country_entities:
            self.entities['GPE'].add((country, source))

        # Create relationships between countries in the same sentence
        for sent in doc.sents:
            sent_doc = self.nlp(sent.text)
            entities_in_sent = [self.standardize_country_name(e.text) for e in sent_doc.ents if e.label_ == "GPE"]
            entities_in_sent = [e for e in entities_in_sent if e]  # Remove None values

            if len(entities_in_sent) >= 2:
                sentiment = self.get_sentiment(sent.text)  # Get sentiment of the sentence
                for i in range(len(entities_in_sent) - 1):
                    self.relationships.append({
                        'source': entities_in_sent[i],
                        'target': entities_in_sent[i + 1],
                        'sentence': sent.text,
                        'sentiment': sentiment
                    })

    def scrape_webpage(self, url):
        """Scrape webpage content from a given URL."""
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, "html.parser")
            paragraphs = [p.text for p in soup.find_all("p")]
            return " ".join(paragraphs)  # Return all text as a single string
        except requests.RequestException as e:
            print(f"Failed to fetch {url}: {e}")
            return ""

    def process_csv(self, csv_file):
        """Process CSV file and analyze extracted text."""
        df = pd.read_csv(csv_file)

        for _, row in df.iterrows():
            link = row.get("Link", "").strip()
            text = row.get("Text", "").strip()

            if link:
                print(f"Scraping: {link}")
                web_text = self.scrape_webpage(link)
                self.extract_entities_and_relationships(web_text, source=link)
            
            if text:
                self.extract_entities_and_relationships(text, source="CSV Data")

    def get_continent(self, country_name):
        """Map country name to a continent."""
        try:
            country_code = pycountry.countries.lookup(country_name).alpha_2
            continent_code = pc.country_alpha2_to_continent_code(country_code)
            continent_map = {
                "NA": "North America", "SA": "South America", "EU": "Europe",
                "AF": "Africa", "AS": "Asia", "OC": "Oceania"
            }
            return continent_map.get(continent_code, "Unknown")
        except:
            return "Unknown"

    def visualize_relationships(self, output_file="country_network.html"):
        """Visualize country relationships using Pyvis with continent-based color coding and improved spacing."""
        
        net = Network(height="900px", width="100%", bgcolor="#222222", font_color="white", notebook=True, cdn_resources='in_line')
        net.force_atlas_2based(gravity=-30, central_gravity=0.02, spring_length=250, spring_strength=0.1)
    
        # Step 1: Keep only the top 30 most mentioned countries
        N = 30
        top_countries = sorted(self.country_mentions.items(), key=lambda x: x[1], reverse=True)[:N]
        top_countries = {country for country, _ in top_countries}
    
        # Step 2: Track relationships and set a lower threshold (>= 2 mentions)
        strong_relationships = defaultdict(int)
        for r in self.relationships:
            strong_relationships[(r['source'], r['target'])] += 1
    
        filtered_relationships = [
            r for r in self.relationships if strong_relationships[(r['source'], r['target'])] >= 3
            and r['source'] in top_countries and r['target'] in top_countries
        ]

        # **Step 3: Ensure added_nodes set exists BEFORE using it**
        added_nodes = set()
    
        # Step 4: Add nodes with continent-based colors
        for country in top_countries:
            continent = self.get_continent(country)
            color = {
                "North America": "red", "South America": "green", "Europe": "blue",
                "Africa": "yellow", "Asia": "purple", "Oceania": "orange"
            }.get(continent, "gray")
    
            size = max(15, min(50, 10 * math.log1p(self.country_mentions[country])))
            net.add_node(country, label=country, color=color, size=size)
            added_nodes.add(country)  # ✅ Track that the node was added
    
        # Step 5: Add edges with sentiment-based colors
        for relation in filtered_relationships:
            source, target, sentiment = relation["source"], relation["target"], relation["sentiment"]
    
            # Ensure both nodes exist before adding the edge
            if source in added_nodes and target in added_nodes:
                edge_color = "green" if sentiment == "POSITIVE" else "red" if sentiment == "NEGATIVE" else "gray"
                net.add_edge(source, target, width=2, color=edge_color, title=relation["sentence"])
    
        # Save and show the graph
        net.show(output_file)

if __name__ == "__main__":
    analyzer = CountrySentimentAnalyzer()
    csv_file = "/Users/benitaleonardi/Documents/news_excerpts_parsed.csv"
    analyzer.process_csv(csv_file)
    analyzer.visualize_relationships("country_network_optimized_vr5.html")
# Out:
# Device set to use mps:0
# Scraping: https://edition.cnn.com/2023/09/29/business/starbucks-union-wages/index.html
# Scraping: https://www.channelnewsasia.com/singapore/su-wenqiang-pleads-guilty-billion-dollar-money-laundering-convicted-4234731
# Scraping: https://edition.cnn.com/2023/05/22/tech/meta-facebook-data-privacy-eu-fine/index.html
# Scraping: https://www.channelnewsasia.com/singapore/billion-dollar-money-laundering-case-zhang-ruijin-sentenced-15-months-jail-4302416
# Scraping: https://edition.cnn.com/2024/03/05/politics/liberty-university-fined-campus-safety/index.html
# Scraping: https://www.euronews.com/2024/02/23/judge-convicts-former-austrian-chancellor-sebastian-kurz
# Scraping: https://edition.cnn.com/2022/07/21/economy/china-fines-didi-data-law-violation-intl-hnk/index.html
# Scraping: https://www.brusselstimes.com/justice-belgium/1011990/two-alleged-leaders-of-vast-drug-trafficking-operation-looking-at-20-years-in-prison
# Scraping: https://www.expats.cz/czech-news/article/former-czech-mp-gets-three-year-jail-term-for-multiple-charges-of-rape
# Scraping: https://www.thelocal.dk/20240311/british-trader-on-trial-in-denmark-for-massive-fraud
# Failed to fetch https://www.thelocal.dk/20240311/british-trader-on-trial-in-denmark-for-massive-fraud: 403 Client Error: Forbidden for url: https://www.thelocal.dk/20240311/british-trader-on-trial-in-denmark-for-massive-fraud
# Scraping: https://edition.cnn.com/2022/08/02/europe/brittney-griner-trial-russia-tuesday/index.html
# Scraping: https://edition.cnn.com/2018/04/16/politics/pruitt-soundproof-booth/index.html
# Scraping: https://news.postimees.ee/7416922/estonian-police-nab-boss-of-lithuanian-car-thieves
# Token indices sequence length is longer than the specified maximum sequence length for this model (643 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2343 > 512). Running this sequence through the model will result in indexing errors
# Error processing chunk: The size of tensor a (2343) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://yle.fi/a/3-12659444
# Scraping: https://icelandmonitor.mbl.is/news/news/2021/10/21/sentenced_to_16_years_in_prison/
# Scraping: https://www.ndtv.com/world-news/renault-nissan-alliance-carlos-ghosn-france-issues-international-arrest-warrant-against-ex-nissan-head-2909763
# Scraping: https://edition.cnn.com/2023/04/19/tech/china-seagate-huawei-penalty-hnk-intl/index.html
# Scraping: https://www.channelnewsasia.com/asia/woman-plead-guilty-negligence-caring-2-babies-nurul-shahira-3504176
# Scraping: https://edition.cnn.com/2023/05/03/business/mcdonalds-child-labor-louisville/index.html
# Scraping: https://edition.cnn.com/2023/04/07/europe/russia-chinese-lgbtq-blogger-arrested-intl/index.html
# Scraping: https://edition.cnn.com/2021/07/30/tech/amazon-eu-privacy-fine/index.html
# Scraping: https://edition.cnn.com/2024/03/07/europe/portugal-election-intl-cmd/index.html
# Scraping: https://edition.cnn.com/2010/WORLD/europe/10/20/czech.republic.arson.verdict/index.html
# Failed to fetch https://edition.cnn.com/2010/WORLD/europe/10/20/czech.republic.arson.verdict/index.html: 404 Client Error: OK for url: https://edition.cnn.com/2010/WORLD/europe/10/20/czech.republic.arson.verdict/index.html
# Scraping: https://www.channelnewsasia.com/asia/tony-chung-exiled-activist-hong-kong-says-paid-informant-china-4016916
# Error processing chunk: The size of tensor a (2431) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://edition.cnn.com/2024/01/22/europe/ian-bailey-murder-dead-scli-intl/index.html
# Scraping: https://edition.cnn.com/2020/06/15/sport/daniel-kinahan-tyson-fury-anthony-joshua-boxing-ireland-spt-intl/index.html
# Error processing chunk: The size of tensor a (2336) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://www.channelnewsasia.com/singapore/red-crowns-senior-living-fined-offence-nursing-home-alternative-4233926
# Error processing chunk: The size of tensor a (2345) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://www.straitstimes.com/singapore/all-natural-eczema-cream-found-to-have-over-430-times-the-allowed-limit-of-arsenic-hsa
# Scraping: https://edition.cnn.com/2022/12/06/politics/trump-organization-fraud-trial-verdict/index.html
# Scraping: https://www.straitstimes.com/singapore/courts-crime/company-director-gets-20-months-jail-152m-penalty-for-offences-related-to-iras-scheme
# Scraping: https://www.channelnewsasia.com/world/greta-thunberg-charged-again-disobeying-police-order-3773416
# Failed to fetch https://www.channelnewsasia.com/world/greta-thunberg-charged-again-disobeying-police-order-3773416: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/greta-thunberg-charged-again-disobeying-police-order-3773416
# Scraping: https://www.reuters.com/world/china/hong-kong-court-convicts-four-rioting-after-2019-legislature-storming-2024-02-01/
# Failed to fetch https://www.reuters.com/world/china/hong-kong-court-convicts-four-rioting-after-2019-legislature-storming-2024-02-01/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/world/china/hong-kong-court-convicts-four-rioting-after-2019-legislature-storming-2024-02-01/
# Scraping: https://edition.cnn.com/2020/01/19/us/alaska-dentist-hoverboard-convicted-trnd/index.html
# Scraping: https://www.channelnewsasia.com/asia/vietnam-court-jails-soft-drinks-tycoon-40-miilion-scam-case-tan-hiep-phat-4291091
# Failed to fetch https://www.channelnewsasia.com/asia/vietnam-court-jails-soft-drinks-tycoon-40-miilion-scam-case-tan-hiep-phat-4291091: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/vietnam-court-jails-soft-drinks-tycoon-40-miilion-scam-case-tan-hiep-phat-4291091
# Scraping: https://www.straitstimes.com/singapore/courts-crime/mfa-director-general-charged-over-use-of-diplomatic-bags-containing-panadol-luxury-watches
# Scraping: https://www.straitstimes.com/tech/tech-news/singapore-firms-fined-75000-for-personal-data-lapses-affecting-over-600000-people
# Scraping: https://www.reuters.com/business/finance/indias-paytm-payments-bank-fined-over-662000-money-laundering-2024-03-01/
# Failed to fetch https://www.reuters.com/business/finance/indias-paytm-payments-bank-fined-over-662000-money-laundering-2024-03-01/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/business/finance/indias-paytm-payments-bank-fined-over-662000-money-laundering-2024-03-01/
# Scraping: https://edition.cnn.com/2023/04/04/business/tiktok-uk-data-regulator-fine/index.html
# Scraping: https://www.channelnewsasia.com/singapore/mas-fines-dbs-ocbc-citibank-swiss-life-breaches-3-8-million-wirecard-3577456
# Scraping: https://www.reuters.com/business/aerospace-defense/indias-aviation-watchdog-fines-air-india-violating-flight-duty-time-limitations-2024-03-22/
# Failed to fetch https://www.reuters.com/business/aerospace-defense/indias-aviation-watchdog-fines-air-india-violating-flight-duty-time-limitations-2024-03-22/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/business/aerospace-defense/indias-aviation-watchdog-fines-air-india-violating-flight-duty-time-limitations-2024-03-22/
# Scraping: https://edition.cnn.com/2022/12/20/investing/wells-fargo-cfpb-foreclosure-fine/index.html
# Scraping: https://www.straitstimes.com/business/apple-hit-with-18-billion-eu-fine-over-app-store-rules
# Scraping: https://www.straitstimes.com/singapore/burger-lobster-fined-3000-for-food-safety-lapses
# Scraping: https://edition.cnn.com/2024/02/22/tech/ftc-avast-cybersecurity-company-fine/index.html
# Scraping: https://www.cbsnews.com/news/dish-fcc-satellite-space-junk-settlement/
# Scraping: https://www.cnbc.com/2022/07/21/china-fines-didi-more-than-1-billion-for-breaking-data-security-laws.html
# Scraping: https://edition.cnn.com/2024/03/23/us/oregon-cold-case-chewing-gum-dna/index.html
# Scraping: https://www.reuters.com/technology/space/musks-spacex-fined-near-amputation-suffered-by-worker-records-show-2024-02-13/
# Failed to fetch https://www.reuters.com/technology/space/musks-spacex-fined-near-amputation-suffered-by-worker-records-show-2024-02-13/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/space/musks-spacex-fined-near-amputation-suffered-by-worker-records-show-2024-02-13/
# Scraping: https://www.reuters.com/world/us/us-regulators-fine-credit-firm-transunion-23-million-over-rent-screening-2023-10-12/
# Failed to fetch https://www.reuters.com/world/us/us-regulators-fine-credit-firm-transunion-23-million-over-rent-screening-2023-10-12/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/world/us/us-regulators-fine-credit-firm-transunion-23-million-over-rent-screening-2023-10-12/
# Scraping: https://www.reuters.com/technology/russian-court-fines-google-508-mln-over-fake-information-ukraine-war-tass-2023-12-20/
# Failed to fetch https://www.reuters.com/technology/russian-court-fines-google-508-mln-over-fake-information-ukraine-war-tass-2023-12-20/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/russian-court-fines-google-508-mln-over-fake-information-ukraine-war-tass-2023-12-20/
# Scraping: https://www.reuters.com/markets/asia/indonesias-anti-trust-body-fines-cooking-oil-firms-restricting-supply-2023-05-26/
# Failed to fetch https://www.reuters.com/markets/asia/indonesias-anti-trust-body-fines-cooking-oil-firms-restricting-supply-2023-05-26/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/markets/asia/indonesias-anti-trust-body-fines-cooking-oil-firms-restricting-supply-2023-05-26/
# Scraping: https://edition.cnn.com/2024/03/06/entertainment/rust-trial-hannah-gutierrez-reed/index.html
# Scraping: https://www.reuters.com/sustainability/boards-policy-regulation/adm-investor-services-fined-anti-money-laundering-failures-2023-10-02/
# Failed to fetch https://www.reuters.com/sustainability/boards-policy-regulation/adm-investor-services-fined-anti-money-laundering-failures-2023-10-02/: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/sustainability/boards-policy-regulation/adm-investor-services-fined-anti-money-laundering-failures-2023-10-02/
# Scraping: https://edition.cnn.com/2024/03/14/tech/tiktok-fine-italy/index.html
# Scraping: https://www.nasdaq.com/articles/italys-antitrust-agency-fines-energy-companies-for-aggressive-billing-0
# Failed to fetch https://www.nasdaq.com/articles/italys-antitrust-agency-fines-energy-companies-for-aggressive-billing-0: HTTPSConnectionPool(host='www.nasdaq.com', port=443): Read timed out. (read timeout=10)
# Scraping: https://edition.cnn.com/2024/03/20/travel/delta-pilot-sentenced-intl-scli-gbr/index.html
# Scraping: https://edition.cnn.com/2024/04/30/business/binance-founder-sentenced-money-laundering/index.html
# Error processing chunk: The size of tensor a (2307) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://www.straitstimes.com/life/entertainment/iranian-director-mohammad-rasoulof-sentenced-to-8-years-in-prison-and-flogging-lawyer
# Scraping: https://www.channelnewsasia.com/world/us-imposes-sweeping-sanctions-russia-targets-over-500-people-entities-4145251
# Scraping: https://www.channelnewsasia.com/world/eu-agrees-new-sanctions-against-russia-ahead-ukraine-war-anniversary-41394766
# Failed to fetch https://www.channelnewsasia.com/world/eu-agrees-new-sanctions-against-russia-ahead-ukraine-war-anniversary-41394766: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/eu-agrees-new-sanctions-against-russia-ahead-ukraine-war-anniversary-41394766
# Scraping: https://www.channelnewsasia.com/world/european-union-sanctions-19-myanmar-officials-froze-assets-3054551
# Scraping: https://www.channelnewsasia.com/world/eu-imposes-sanctions-human-rights-violations-ukraine-russia-and-other-countries-3643066
# Failed to fetch https://www.channelnewsasia.com/world/eu-imposes-sanctions-human-rights-violations-ukraine-russia-and-other-countries-3643066: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/eu-imposes-sanctions-human-rights-violations-ukraine-russia-and-other-countries-3643066
# Scraping: https://www.channelnewsasia.com/world/eu-targets-iran-over-protest-crackdown-russia-drone-sales-3139606
# Scraping: https://www.channelnewsasia.com/asia/chinese-app-tiktok-cuts-jobs-india-following-ban-441901
# Scraping: https://www.channelnewsasia.com/world/eu-sanctions-belarus-officials-lukashenko-729336
# Scraping: https://www.channelnewsasia.com/world/cuba-blames-us-rising-migrant-traffic-thru-central-america-3821536
# Failed to fetch https://www.channelnewsasia.com/world/cuba-blames-us-rising-migrant-traffic-thru-central-america-3821536: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/cuba-blames-us-rising-migrant-traffic-thru-central-america-3821536
# Scraping: https://www.channelnewsasia.com/world/us-issues-new-sanctions-against-top-russian-ally-belarus-3688336
# Failed to fetch https://www.channelnewsasia.com/world/us-issues-new-sanctions-against-top-russian-ally-belarus-3688336: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/us-issues-new-sanctions-against-top-russian-ally-belarus-3688336
# Scraping: https://www.channelnewsasia.com/world/us-sanctions-will-not-make-russia-stop-protecting-its-interests-russian-ambassador-4145586
# Scraping: https://www.channelnewsasia.com/asia/china-sanctions-lithuanian-deputy-minister-taiwan-visit-2877111
# Scraping: https://www.channelnewsasia.com/world/us-imposes-more-sanctions-money-lending-network-tied-yemens-houthi-rebels-4015071
# Scraping: https://www.channelnewsasia.com/world/navalnys-death-uk-sanctions-heads-russian-prison-4139081
# Scraping: https://www.channelnewsasia.com/commentary/singapore-sanctions-russia-ukraine-war-economic-impact-prices-petrol-electricity-2614031
# Scraping: https://www.channelnewsasia.com/asia/global-community-steps-financial-pressure-myanmar-military-junta-international-sanctions-singapore-bank-uob-3740016
# Scraping: https://www.channelnewsasia.com/world/us-expands-sanctions-myanmar-jet-fuel-cites-junta-airstrikes-3719476
# Failed to fetch https://www.channelnewsasia.com/world/us-expands-sanctions-myanmar-jet-fuel-cites-junta-airstrikes-3719476: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/us-expands-sanctions-myanmar-jet-fuel-cites-junta-airstrikes-3719476
# Scraping: https://www.channelnewsasia.com/business/north-korea-economy-shrank-third-year-2022-souths-central-bank-3660721
# Failed to fetch https://www.channelnewsasia.com/business/north-korea-economy-shrank-third-year-2022-souths-central-bank-3660721: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/north-korea-economy-shrank-third-year-2022-souths-central-bank-3660721
# Scraping: https://www.channelnewsasia.com/commentary/north-korea-kim-jong-un-covid-cases-food-shortage-trade-sanction-china-2132416
# Error processing chunk: The size of tensor a (2442) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: http://edition.cnn.com/2011/WORLD/asiapcf/09/06/israel.turkey/index.html
# Failed to fetch http://edition.cnn.com/2011/WORLD/asiapcf/09/06/israel.turkey/index.html: 404 Client Error: OK for url: https://edition.cnn.com/2011/WORLD/asiapcf/09/06/israel.turkey/index.html
# Scraping: https://www.channelnewsasia.com/asia/china-threatens-more-trade-sanctions-taiwan-election-nears-4012396
# Failed to fetch https://www.channelnewsasia.com/asia/china-threatens-more-trade-sanctions-taiwan-election-nears-4012396: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/china-threatens-more-trade-sanctions-taiwan-election-nears-4012396
# Scraping: https://www.channelnewsasia.com/asia/taiwan-apec-forum-offers-rare-chance-break-china-bonds-3922906
# Error processing chunk: The size of tensor a (2406) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://www.channelnewsasia.com/asia/hong-kongs-top-judge-defends-courts-amid-western-concerns-4065506
# Failed to fetch https://www.channelnewsasia.com/asia/hong-kongs-top-judge-defends-courts-amid-western-concerns-4065506: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/hong-kongs-top-judge-defends-courts-amid-western-concerns-4065506
# Scraping: https://www.channelnewsasia.com/singapore/russia-sanctions-evade-singapore-company-director-serena-ng-3252226
# Scraping: https://www.businesstimes.com.sg/international/australia-threatens-wto-action-china-hikes-duty-wine
# Scraping: https://www.channelnewsasia.com/world/united-states-sanctions-myanmar-defence-ministry-banks-arms-foreign-sources-3577926
# Failed to fetch https://www.channelnewsasia.com/world/united-states-sanctions-myanmar-defence-ministry-banks-arms-foreign-sources-3577926: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/united-states-sanctions-myanmar-defence-ministry-banks-arms-foreign-sources-3577926
# Scraping: https://www.channelnewsasia.com/world/venezuela-global-oil-stage-united-states-sanctions-world-energy-crunch-donald-trump-nicolas-maduro-russia-ukraine-3243131
# Scraping: https://www.channelnewsasia.com/asia/fukushima-radioactive-water-release-iaea-south-korea-japan-3616341
# Failed to fetch https://www.channelnewsasia.com/asia/fukushima-radioactive-water-release-iaea-south-korea-japan-3616341: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/fukushima-radioactive-water-release-iaea-south-korea-japan-3616341
# Scraping: https://www.channelnewsasia.com/world/russia-says-new-south-korean-sanctions-are-unfriendly-will-respond-4240326
# Scraping: https://www.channelnewsasia.com/asia/us-will-not-invite-sanctioned-hong-kong-leader-john-lee-apec-3663131
# Failed to fetch https://www.channelnewsasia.com/asia/us-will-not-invite-sanctioned-hong-kong-leader-john-lee-apec-3663131: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/us-will-not-invite-sanctioned-hong-kong-leader-john-lee-apec-3663131
# Scraping: https://www.channelnewsasia.com/business/sanctioned-china-stocks-win-sudden-boost-patriotic-buyers-3517131
# Failed to fetch https://www.channelnewsasia.com/business/sanctioned-china-stocks-win-sudden-boost-patriotic-buyers-3517131: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/sanctioned-china-stocks-win-sudden-boost-patriotic-buyers-3517131
# Scraping: https://www.channelnewsasia.com/asia/china-sanction-5-us-manufacturers-over-arms-sales-taiwan-4029751
# Failed to fetch https://www.channelnewsasia.com/asia/china-sanction-5-us-manufacturers-over-arms-sales-taiwan-4029751: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/china-sanction-5-us-manufacturers-over-arms-sales-taiwan-4029751
# Scraping: https://www.channelnewsasia.com/business/us-slaps-sanctions-greek-spyware-vendor-says-it-targeted-us-officials-4173541
# Scraping: https://www.channelnewsasia.com/commentary/us-airstrikes-iraq-syria-iran-jordan-attack-snap-insight-4096871
# Scraping: https://www.channelnewsasia.com/world/uk-and-us-sanction-senior-houthis-over-red-sea-shipping-attacks-4075036
# Failed to fetch https://www.channelnewsasia.com/world/uk-and-us-sanction-senior-houthis-over-red-sea-shipping-attacks-4075036: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/uk-and-us-sanction-senior-houthis-over-red-sea-shipping-attacks-4075036
# Scraping: https://www.channelnewsasia.com/business/exclusive-us-targets-chinas-top-chipmaking-plant-after-huawei-mate-60-pro-sources-say-4139131
# Scraping: https://www.channelnewsasia.com/business/taiwan-probes-four-firms-accused-helping-chinas-huawei-3825726
# Failed to fetch https://www.channelnewsasia.com/business/taiwan-probes-four-firms-accused-helping-chinas-huawei-3825726: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/taiwan-probes-four-firms-accused-helping-chinas-huawei-3825726
# Scraping: https://www.straitstimes.com/world/canada-sanctions-17-saudi-nationals-over-khashoggi-killing
# Scraping: https://www.channelnewsasia.com/world/china-pompeo-other-trump-officials-sanctions-424266
# Scraping: https://apnews.com/article/japan-south-north-korea-unification-minister-a399cb15715d827105563f279a9996e1#:~:text=In%202019%2C%20Japan%27s%20government%20tightened,restoring%20each%20other%27s%20trade%20status.
# Scraping: https://apnews.com/united-states-government-general-news-60bc85e527d0455eb6fd49d9535db185
# Error processing chunk: The size of tensor a (2442) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://edition.cnn.com/2019/05/02/india/masood-azhar-un-sanctions-intl/index.html
# Scraping: https://www.channelnewsasia.com/world/us-uk-unveil-sweeping-sanctions-iran-after-attack-israel-4275611
# Failed to fetch https://www.channelnewsasia.com/world/us-uk-unveil-sweeping-sanctions-iran-after-attack-israel-4275611: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/us-uk-unveil-sweeping-sanctions-iran-after-attack-israel-4275611
# Scraping: https://www.ctvnews.ca/politics/canada-sanctions-iranians-accused-of-violently-repressing-women-and-girls-1.6799720
# Scraping: https://www.channelnewsasia.com/world/hamas-funding-money-crypto-taxation-investments-israel-war-conflict-gaza-3911911
# Error processing chunk: The size of tensor a (2546) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://www.hrw.org/news/2024/02/06/australias-myanmar-sanctions-step-forward
# Scraping: https://www.bbc.com/news/uk-politics-68654533
# Scraping: https://www.bbc.com/news/uk-68274777
# Scraping: https://www.channelnewsasia.com/asia/us-sanctions-russian-entities-digital-currency-sanctions-evasion-4220806
# Scraping: https://www.channelnewsasia.com/world/us-weighing-tougher-sanctions-russia-2463461
# Scraping: https://uniglobalunion.org/news/sanctions-myanmar-state-owned-banks/
# Scraping: https://www.koreatimes.co.kr/www/nation/2024/04/103_367050.html
# Scraping: https://in-cyprus.philenews.com/international/eu-imposes-sanctions-against-violent-west-bank-settlers/
# Failed to fetch https://in-cyprus.philenews.com/international/eu-imposes-sanctions-against-violent-west-bank-settlers/: 403 Client Error: Forbidden for url: https://in-cyprus.philenews.com/international/eu-imposes-sanctions-against-violent-west-bank-settlers/
# Scraping: https://www.channelnewsasia.com/business/sechin-lauds-safety-russian-oil-sales-china-amid-chaos-middle-east-3857766
# Failed to fetch https://www.channelnewsasia.com/business/sechin-lauds-safety-russian-oil-sales-china-amid-chaos-middle-east-3857766: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/business/sechin-lauds-safety-russian-oil-sales-china-amid-chaos-middle-east-3857766
# Scraping: https://au.news.yahoo.com/canada-slaps-more-sanctions-belarus-151901047.html
# Scraping: https://www.channelnewsasia.com/business/samsung-pay-stop-working-russias-mir-payment-system-april-3-4225746
# Scraping: https://www.inqld.com.au/business/2024/02/27/chinese-sanctions-on-wine-worth-1-billion-to-be-lifted-by-end-of-month-minister
# Failed to fetch https://www.inqld.com.au/business/2024/02/27/chinese-sanctions-on-wine-worth-1-billion-to-be-lifted-by-end-of-month-minister: 403 Client Error: Forbidden for url: https://www.inqld.com.au/business/2024/02/27/chinese-sanctions-on-wine-worth-1-billion-to-be-lifted-by-end-of-month-minister
# Scraping: https://www.independent.co.ug/sudan-denounces-eu-sanctions-against-economic-institutions-as-unjust/
# Failed to fetch https://www.independent.co.ug/sudan-denounces-eu-sanctions-against-economic-institutions-as-unjust/: 403 Client Error: Forbidden for url: https://www.independent.co.ug/sudan-denounces-eu-sanctions-against-economic-institutions-as-unjust/
# Scraping: https://www.channelnewsasia.com/world/china-summons-foreign-diplomats-protest-sanctions-274581
# Error processing chunk: The size of tensor a (2505) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://www.channelnewsasia.com/world/eu-adds-russias-biggest-diamond-producer-alrosa-sanctions-list-4022721
# Failed to fetch https://www.channelnewsasia.com/world/eu-adds-russias-biggest-diamond-producer-alrosa-sanctions-list-4022721: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/eu-adds-russias-biggest-diamond-producer-alrosa-sanctions-list-4022721
# Scraping: https://www.channelnewsasia.com/business/chevron-hands-myanmar-gas-field-stake-junta-thailands-pttep-4252191
# Error processing chunk: The size of tensor a (2360) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://web.archive.org/web/20240331095538/https://www.channelnewsasia.com/world/israel-starvation-weapon-war-gaza-hamas-4205971
# Scraping: https://www.channelnewsasia.com/cna-insider/why-southeast-asia-should-worry-if-afghanistan-fails-terrorism-expert-2160036
# Scraping: https://www.channelnewsasia.com/commentary/ukraine-war-second-anniversary-russia-invasion-west-support-us-eu-nato-4144521
# Scraping: https://reliefweb.int/report/democratic-republic-congo/dr-congo-spotlight-equateur-crisis
# Scraping: https://www.channelnewsasia.com/commentary/taliban-press-conference-first-wants-world-trust-2122781
# Scraping: https://www.channelnewsasia.com/asia/exodus-thailand-continues-after-fall-key-myanmar-border-town-4260436
# Scraping: https://www.channelnewsasia.com/asia/asias-toughest-jobs-thai-border-patrol-soldier-who-risks-his-life-every-day-1008846
# Scraping: https://www.channelnewsasia.com/asia/thailand-myanmar-border-clashes-military-junta-4260386
# Failed to fetch https://www.channelnewsasia.com/asia/thailand-myanmar-border-clashes-military-junta-4260386: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/asia/thailand-myanmar-border-clashes-military-junta-4260386
# Scraping: https://www.channelnewsasia.com/commentary/myanmar-civil-war-coup-opposition-resistance-ceasefire-4059991
# Scraping: https://www.channelnewsasia.com/world/sudan-war-rages-truce-extension-fighting-dead-injured-fled-3451596
# Failed to fetch https://www.channelnewsasia.com/world/sudan-war-rages-truce-extension-fighting-dead-injured-fled-3451596: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/sudan-war-rages-truce-extension-fighting-dead-injured-fled-3451596
# Scraping: https://www.channelnewsasia.com/world/millions-sudanese-go-hungry-war-disrupts-food-supply-4175496
# Error processing chunk: The size of tensor a (2306) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://www.hrw.org/world-report/2022/country-chapters/cameroon
# Scraping: https://www.channelnewsasia.com/world/russian-forces-appear-shift-siege-warfare-ukraine-us-official-2523711
# Scraping: https://www.theguardian.com/world/2010/may/24/gangs-barricade-kingston-jamaica
# Scraping: https://www.channelnewsasia.com/world/islamic-state-claims-responsibility-deadly-philippine-bombing-3963006
# Failed to fetch https://www.channelnewsasia.com/world/islamic-state-claims-responsibility-deadly-philippine-bombing-3963006: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/islamic-state-claims-responsibility-deadly-philippine-bombing-3963006
# Scraping: https://www.bbc.com/news/world-asia-67690614
# Scraping: https://www.channelnewsasia.com/asia/answer-marawi-extremism-seen-more-just-religion-994156
# Scraping: https://www.channelnewsasia.com/world/rise-mexican-cartel-violence-drives-record-migration-us-3991871
# Failed to fetch https://www.channelnewsasia.com/world/rise-mexican-cartel-violence-drives-record-migration-us-3991871: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/rise-mexican-cartel-violence-drives-record-migration-us-3991871
# Scraping: https://www.newsweek.com/nigeria-oil-yemi-osinbajo-niger-delta-629964
# Failed to fetch https://www.newsweek.com/nigeria-oil-yemi-osinbajo-niger-delta-629964: 403 Client Error: Forbidden for url: https://www.newsweek.com/nigeria-oil-yemi-osinbajo-niger-delta-629964
# Scraping: https://www.channelnewsasia.com/commentary/us-uk-houthi-strike-yemen-iran-gaza-war-international-law-4111146
# Scraping: https://www.newsweek.com/tompolo-niger-delta-avengers-nigeria-oil-616154
# Failed to fetch https://www.newsweek.com/tompolo-niger-delta-avengers-nigeria-oil-616154: 403 Client Error: Forbidden for url: https://www.newsweek.com/tompolo-niger-delta-avengers-nigeria-oil-616154
# Scraping: https://www.africanews.com/2024/03/07/at-least-10-people-killed-as-rebels-seize-a-town-in-congos-conflict-hit-eastern-region//
# Scraping: https://apnews.com/article/congo-north-kivu-ituri-goma-violence-conflict-tshisekedi-0c1990292498e65875cd7f989b65f641
# Error processing chunk: The size of tensor a (2289) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://www.channelnewsasia.com/world/us-strike-iraq-syria-retaliatory-jordan-attack-us-soldiers-iran-4096421
# Scraping: https://www.dw.com/en/dr-congo-conflict-pulls-in-more-players-to-tackle-rebels/a-68304390
# Scraping: https://www.africanews.com/2023/12/28/central-african-republic-peacekeepers-deployed-in-the-area-of-a-massacre-of-23-civilians//
# Scraping: https://www.channelnewsasia.com/world/united-states-forces-under-fire-middle-east-conflict-widens-3909331
# Failed to fetch https://www.channelnewsasia.com/world/united-states-forces-under-fire-middle-east-conflict-widens-3909331: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/united-states-forces-under-fire-middle-east-conflict-widens-3909331
# Scraping: https://www.channelnewsasia.com/world/us-sanctions-iran-targets-over-jordan-attack-4095701
# Scraping: https://www.channelnewsasia.com/world/israel-hamas-war-defence-minister-retaliatory-actions-iraq-yemen-iran-4011271
# Failed to fetch https://www.channelnewsasia.com/world/israel-hamas-war-defence-minister-retaliatory-actions-iraq-yemen-iran-4011271: 404 Client Error: Not Found for url: https://www.channelnewsasia.com/world/israel-hamas-war-defence-minister-retaliatory-actions-iraq-yemen-iran-4011271
# Scraping: https://www.channelnewsasia.com/world/usa-invasion-iraq-20-years-anniversary-analysts-3359621
# Scraping: https://www.thenation.com/article/archive/central-african-republics-forgotten-crisis/
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2475) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2450) must match the size of tensor b (512) at non-singleton dimension 1
# Error processing chunk: The size of tensor a (2430) must match the size of tensor b (512) at non-singleton dimension 1
# Scraping: https://www.bbc.com/news/world-latin-america-63373068
# Scraping: https://www.channelnewsasia.com/world/iraq-armed-groups-united-states-iran-islamic-state-attacks-jordan-response-dial-down-esmil-qaani-baghdad-4132306

# %%
# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

# Load Hugging Face Transformers Sentiment Model
sentiment_pipeline = pipeline('sentiment-analysis', model='distilbert-base-uncased-finetuned-sst-2-english')

class PDFTextAnalyzer:
    def __init__(self):
        """Initialize the text analyzer with NLP and data structures."""
        self.nlp = nlp  # Use loaded SpaCy model
        self.entities = defaultdict(set)
        self.relationships = []

    def standardize_country_name(self, country):
        """Attempt to standardize country names using pycountry."""
        try:
            return pycountry.countries.lookup(country).name
        except LookupError:
            return None  # Ignore non-country entities

    def get_sentiment(self, sentence):
        """Analyze sentiment of a sentence using Transformers."""
        result = sentiment_pipeline(sentence)
        sentiment_label = result[0]['label']  # 'POSITIVE' or 'NEGATIVE'
        confidence = result[0]['score']

        # If confidence is low, classify as NEUTRAL
        if confidence < 0.7:
            return 'NEUTRAL'
        return sentiment_label

    def extract_entities_and_relationships(self, text, source=None):
        """Extract country entities (GPE) and relationships from text."""
        doc = self.nlp(text)
        country_entities = set()

        for ent in doc.ents:
            if ent.label_ == "GPE":
                country_name = self.standardize_country_name(ent.text)
                if country_name:  # Only add valid countries
                    country_entities.add((country_name, source))

        # Store valid countries
        for country in country_entities:
            self.entities['GPE'].add(country)

        # Create relationships between countries in the same sentence
        for sent in doc.sents:
            sent_doc = self.nlp(sent.text)
            entities_in_sent = [self.standardize_country_name(e.text) for e in sent_doc.ents if e.label_ == "GPE"]
            entities_in_sent = [e for e in entities_in_sent if e]  # Remove None values

            if len(entities_in_sent) >= 2:
                sentiment = self.get_sentiment(sent.text)  # Get sentiment of the sentence
                for i in range(len(entities_in_sent) - 1):
                    self.relationships.append({
                        'source': entities_in_sent[i],
                        'target': entities_in_sent[i + 1],
                        'sentence': sent.text,
                        'sentiment': sentiment
                    })

    def extract_text_from_pdf(self, pdf_file):
        """Extract text from a PDF file using PyPDF2."""
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            extracted_text = page.extract_text()
            if extracted_text:
                text += extracted_text
        return text

    def process_directory(self, directory):
        """Process all PDFs in a directory."""
        for filename in os.listdir(directory):
            if filename.endswith(".pdf"):
                pdf_path = os.path.join(directory, filename)
                with open(pdf_path, "rb") as pdf_file:
                    text = self.extract_text_from_pdf(pdf_file)
                    self.extract_entities_and_relationships(text, source=filename)

    
    def visualize_relationships(self, output_file="country_network.html"):
        """Visualize country relationships using Pyvis with sentiment-based colors & filtering."""
        
        # Initialize network graph
        net = Network(height="750px", width="100%", bgcolor="#222222", font_color="white", notebook=True, cdn_resources='in_line')
    
        # Improve graph spacing
        net.set_options('''
        var options = {
          "physics": {
            "barnesHut": {
              "gravitationalConstant": -2500,
              "springLength": 300,
              "damping": 0.7
            }
          }
        }
        ''')
    
        # Keep only relationships that appear at least 3 times
        strong_relationships = defaultdict(int)
        for r in self.relationships:
            strong_relationships[(r['source'], r['target'])] += 1
        
        filtered_relationships = [
            r for r in self.relationships if strong_relationships[(r['source'], r['target'])] >= 3
        ]

        # Collect unique country nodes from filtered relationships
        countries = set()
        for relation in filtered_relationships:
            countries.add(relation['source'])
            countries.add(relation['target'])
    
        # Add nodes with size based on mentions
        for country in countries:
            size = max(15, min(50, 8 * math.log1p(self.country_mentions[country])))  # Log-scaled size
            net.add_node(country, label=country, color="blue", size=size)
    
        # Add filtered edges with sentiment-based color
        for relation in filtered_relationships:
            sentiment = relation['sentiment']
            edge_color = {"POSITIVE": "green", "NEGATIVE": "red", "NEUTRAL": "gray"}.get(sentiment, "gray")
            net.add_edge(relation['source'], relation['target'], width=2, color=edge_color, title=relation['sentence'])

if __name__ == "__main__":
    pdf_directory = "/Users/benitaleonardi/Downloads/Datathon pdfs"
    #analyzer = PDFTextAnalyzer()
    #analyzer.process_directory(pdf_directory)  # Process all PDFs in the specified directory
    analyzer.visualize_relationships("country_network.html")  # Visualize the relationships between countries
# Out:
# Device set to use mps:0
# country_network.html
